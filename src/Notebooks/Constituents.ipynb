# %% [markdown]
# This notebook explains all the steps taken to pre-process the unigram dataset.

# %%
import csv
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
from scipy.interpolate import interp1d
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def tf(x):
    return 1+np.log10(x)

from itertools import groupby
from operator import itemgetter
import pickle as pkl
import re
def patternmaker(x):
    x=np.array(x.notnull())
    x=x.astype(int)
    #print(x)
    val = ''.join(map(str, x))
    #print(val)
    return val
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Introduction
#
# The datasets are from the site http://www.ngrams.info/download_coha.asp.
# For my experimentation, I wanted to see if this dataset could be a candidate for novel compound prediction.
#
# The uni-gram dataset has the following fields -
# 1. count - Frequency of the uni-gram
# 2. unigram - The uni-gram
# 3. pos - The POS of the uni-gram, and
# 4. decade -The decade timestamp, where 1 is for 1810s, 2 for 1820s and so on.
#
#
#
# For the initial trials I looked only into noun-noun compounds (I did perform experiments with adjective noun pairs, but many non compounds were returned).

# %%
unigram=pd.read_csv("1_pos_y_cs_y.txt",quotechar='"',delimiter="\t",quoting=csv.QUOTE_ALL,encoding='cp1252',skiprows=[1])
unigram.columns=['count','unigram','pos','decade']

# %%
pos_counts=unigram.pos.value_counts().to_frame()
pos_counts['perc']=round((pos_counts.pos/pos_counts.pos.sum())*100,3)
pos_counts.head(10)
# Out:
#         pos   perc
# nn1  941021 28.739
# jj   518965 15.849
# np1  497243 15.186
# nn2  402833 12.302
# vv0  167451  5.114
# vvg  116916  3.571
# vvd  109428  3.342
# vvn  107973  3.297
# vvz   83968  2.564
# vvi   83037  2.536

# %% [markdown]
# If we look at the pos tags, we see that there are about 280 of them. The POS tag description is provided on
# http://ucrel.lancs.ac.uk/claws7tags.html. The large value of possible tags is due to the presence of “DITTO
# Tags” (explanation found at the bottom of the webpage).

# %% [markdown]
# # Selection of only noun tags

# %% [markdown]
# From the tag explainations, nn, nn1 and nn2 are tags for common nouns (the '1' and '2' denote if the noun is singular or plural).

# %%
noun_tags=["nn","nn1","nn2"]
#adj_tags=["jj"]
unigram=unigram[unigram.pos.isin(noun_tags)]
nouns=dict.fromkeys(noun_tags,'noun')
#adj=dict.fromkeys(adj_tags,'adj')
unigram.head(10)
# Out:
#      count unigram  pos  decade
# 390      3  aaaagh  nn1      16
# 401      6   AAAct  nn1      13
# 403      1    Aaah  nn1      11
# 404      1    Aaah  nn1      13
# 405      1    Aaah  nn1      18
# 424      1   Aaahh  nn1      13
# 425      1   Aaahh  nn1      15
# 426      4  Aaahhh  nn1      17
# 427      1  Aaahhh  nn1      18
# 428      1   aaahs  nn2      16

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# As we see from the table above, the large number of tags should not be a concern as most have really small frequencies.

# %% [markdown]
# If we look at the count of words per decade, we see that the counts are increasing.
# This should of course, come at no surprise.

# %%
decade_counts=unigram.decade.value_counts().to_frame()
decade_counts['perc']=round((decade_counts.decade/decade_counts.decade.sum())*100,3)
decade_counts
# Out:
#     decade  perc
# 18   96300 7.133
# 17   94589 7.006
# 15   93709 6.941
# 16   92347 6.840
# 13   91461 6.774
# 14   91456 6.774
# 12   91297 6.762
# 10   82825 6.135
# 11   82746 6.129
# 9    77059 5.708
# 8    74597 5.525
# 6    71373 5.286
# 7    70830 5.246
# 5    64345 4.766
# 4    63728 4.720
# 3    56750 4.203
# 2    36983 2.739
# 1    17715 1.312

# %%
decade_counts.drop('decade',axis=1).plot.bar()

# %%
#possibile_tags=["nn","nn1","nn2","jj"]
noun_counts=pos_counts[pos_counts.index.isin(noun_tags)]
print(noun_counts)
print("\n Percentage of words that are nouns is ", round(noun_counts.perc.sum(),3) ,"%")
# Out:
#         pos   perc
# nn1  941021 28.739
# nn2  402833 12.302
# nn     6256  0.191
#
#  Percentage of words that are nouns is  41.232 %

# %% [markdown]
# # Lemmatization

# %% [markdown]
# Lemmatization is performed on the dataset so that both singular and plural nouns get lemmatized to their common lemma form.

# %%
unigram.drop(['pos'],axis=1,inplace=True)

# %%
unigram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350110 entries, 390 to 3274396
# Data columns (total 3 columns):
# count      1350110 non-null int64
# unigram    1350096 non-null object
# decade     1350110 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 41.2+ MB

# %%
unigram['unigram']=unigram['unigram'].str.lower()
unigram['word']=unigram['unigram'].apply(lambda x: lemmatizer.lemmatize(str(x)))
unigram.drop(['unigram'],axis=1,inplace=True)



display(unigram.head(10))
unigram.info()
# Out:
#      count  decade    word
# 390      3      16  aaaagh
# 401      6      13   aaact
# 403      1      11    aaah
# 404      1      13    aaah
# 405      1      18    aaah
# 424      1      13   aaahh
# 425      1      15   aaahh
# 426      4      17  aaahhh
# 427      1      18  aaahhh
# 428      1      16   aaahs
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350110 entries, 390 to 3274396
# Data columns (total 3 columns):
# count     1350110 non-null int64
# decade    1350110 non-null int64
# word      1350110 non-null object
# dtypes: int64(2), object(1)
# memory usage: 41.2+ MB

# %% [markdown]
# Following operations were performed -
#
# 1. substitute all noun tags with 'noun'
# 2. merge the unigram and its tag together
# 3. reduce all words to lowercase

# %% [markdown]
# Some rows need to be merged after the tag class being simplified.
#
# Also only words occuring at least 3 times in a decade are chosen.

# %%
unigram=unigram.groupby(['word','decade'])['count'].sum().to_frame()
unigram=unigram.reset_index(level=['word','decade'])
#unigram=unigram[unigram['count']>=10]
display(unigram.head(10))
unigram.info()
# Out:
#   word  decade  count
# 0    a       2      1
# 1    a       3      1
# 2    a       6    155
# 3    a       7     20
# 4    a       8    226
# 5    a       9     38
# 6    a      10     32
# 7    a      11      2
# 8    a      12     15
# 9    a      13      2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873800 entries, 0 to 873799
# Data columns (total 3 columns):
# word      873800 non-null object
# decade    873800 non-null int64
# count     873800 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 20.0+ MB

# %% [markdown]
# # Shallow to dense representation

# %% [markdown]
# We can now finally pivot the dataset (convert it from a shallow to dense represenation).
#
#
# I have also added 3 extra columns which are,
#
# **cf** : Collection frequency, which is the log of the sum of the term across decades, ie log(1+sum(term).
#
# **presence** : Number of decades a term is present in.
#
# **pattern** : A string that is of length 18. A 0 if the word was not present in the particular decade and 1 otherwise. Could be useful later on during the LSTM reprsentation.
#
# Also, the decades are now suitably labeled.
#
# In order to reduce bias against words with extremely high frequencies, all counts are logarithmically reduced.

# %%
unigram=unigram.pivot(index='word',columns='decade',values='count')
unigram.columns=['1810s','1820s','1830s','1840s','1850s','1860s','1870s','1880s','1890s','1900s','1910s','1920s','1930s','1940s','1950s','1960s','1970s','1980s']
#unigram = unigram.fillna(0)
#unigram[unigram.index.str.contains("['-]")==False]
unigram['cf']=unigram.sum(axis=1)
unigram['presence']=unigram.drop('cf',axis=1).count(axis=1)

#unigram['idf']=np.log10(18/unigram['presence'])
unigram['presence']=unigram["presence"].astype('category')
#unigram[unigram.columns[:-2]]=unigram[unigram.columns[:-2]].applymap(tf)
unigram['pattern']=unigram[unigram.columns[:-2]].apply(patternmaker,axis=1)
#unigram['term_weight']=unigram['cf']*unigram['idf']
display(unigram.head(10))
unigram.info()
# Out:
#          1810s  1820s  1830s  1840s  1850s   1860s  1870s   1880s  1890s  \
# word
# a          nan  1.000  1.000    nan    nan 155.000 20.000 226.000 38.000
# a'been     nan  2.000    nan    nan    nan     nan    nan   1.000    nan
# a'bowl     nan    nan    nan    nan    nan     nan    nan     nan    nan
# a'goin     nan    nan    nan    nan    nan     nan    nan   2.000    nan
# a'here     nan    nan    nan    nan  3.000     nan    nan     nan    nan
# a'ku       nan    nan    nan    nan    nan     nan    nan     nan    nan
# a'nd       nan    nan  1.000    nan  1.000     nan    nan     nan    nan
# a'r        nan    nan    nan    nan    nan   1.000    nan  14.000  5.000
# a'ready    nan    nan  4.000  4.000  9.000   4.000  3.000  17.000  3.000
# a'se       nan    nan    nan    nan    nan     nan    nan   3.000    nan
#
#          1900s         ...          1920s  1930s  1940s  1950s  1960s  1970s  \
# word                   ...
# a       32.000         ...         15.000  2.000  5.000  1.000    nan    nan
# a'been     nan         ...            nan    nan    nan    nan    nan    nan
# a'bowl     nan         ...            nan    nan  3.000    nan    nan    nan
# a'goin   1.000         ...            nan    nan    nan    nan    nan    nan
# a'here     nan         ...            nan    nan    nan    nan    nan    nan
# a'ku       nan         ...            nan  4.000    nan    nan    nan    nan
# a'nd     1.000         ...          1.000    nan  1.000    nan    nan    nan
# a'r      1.000         ...            nan    nan    nan    nan    nan    nan
# a'ready 13.000         ...          3.000  9.000  6.000    nan  1.000  1.000
# a'se       nan         ...            nan    nan    nan    nan    nan    nan
#
#          1980s      cf  presence             pattern
# word
# a          nan 498.000        12  011001111111111000
# a'been     nan   3.000         2  010000010000000000
# a'bowl     nan   3.000         1  000000000000010000
# a'goin     nan   5.000         3  000000010110000000
# a'here     nan   3.000         1  000010000000000000
# a'ku       nan   4.000         1  000000000000100000
# a'nd       nan   6.000         6  001010000111010000
# a'r        nan  21.000         4  000001011100000000
# a'ready  1.000  93.000        15  001111111111110111
# a'se       nan   3.000         1  000000010000000000
#
# [10 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 168819 entries, a to zzo
# Data columns (total 21 columns):
# 1810s       11567 non-null float64
# 1820s       24756 non-null float64
# 1830s       37561 non-null float64
# 1840s       41693 non-null float64
# 1850s       41987 non-null float64
# 1860s       47247 non-null float64
# 1870s       46482 non-null float64
# 1880s       49230 non-null float64
# 1890s       50551 non-null float64
# 1900s       53949 non-null float64
# 1910s       53423 non-null float64
# 1920s       58633 non-null float64
# 1930s       59406 non-null float64
# 1940s       58650 non-null float64
# 1950s       60170 non-null float64
# 1960s       58095 non-null float64
# 1970s       59930 non-null float64
# 1980s       60470 non-null float64
# cf          168819 non-null float64
# presence    168819 non-null category
# pattern     168819 non-null object
# dtypes: category(1), float64(19), object(1)
# memory usage: 27.2+ MB

# %%
unigram.cf.sum()
# Out:
# 63955407.0

# %%
unigram.to_csv('unigrams.csv',sep="\t")

# %% [markdown]
# # End of Report
#
# All the details below are not important for the Novel Compound Generation and were for data analysis.

# %% [markdown]
# The NANs in the above dataset are when words were not present for the particular decade.
# Even after certain pre-processing steps, the dataset appears to be messy due to presence of
# 1. Words such as “a-blowin_noun”,“a'throat_noun” (which might need to be parsed further),
# 2. Words such as “a'mighty_noun”, a'ready_noun (which seem to be missing letters)
# 3. words such as “zwei_noun” (which are not used in english).
# There also exist several uni-grams that are compound nouns already.

# %%
#unigram.loc[["a-blowin_noun","a'throat_noun","a'mighty_noun","zwei_noun"]]
unigram.index.get_loc('bed_noun')
# Out:
# 7917

# %% [markdown]
# There also exist several uni-grams that are compound nouns already.

# %%
unigram.shape
# Out:
# (108894, 21)

# %%
unigram.describe()
# Out:
#          1810s     1820s     1830s     1840s     1850s     1860s     1870s  \
# count 6083.000 12558.000 19461.000 21610.000 21344.000 24791.000 23901.000
# mean     2.126     2.265     2.266     2.255     2.255     2.206     2.240
# std      0.556     0.702     0.741     0.745     0.746     0.723     0.733
# min      1.477     1.477     1.477     1.477     1.477     1.477     1.477
# 25%      1.699     1.699     1.699     1.602     1.602     1.602     1.602
# 50%      2.000     2.079     2.041     2.041     2.041     1.954     2.041
# 75%      2.491     2.716     2.716     2.699     2.699     2.607     2.653
# max      4.245     4.996     5.291     5.443     5.403     5.416     5.463
#
#           1880s     1890s     1900s     1910s     1920s     1930s     1940s  \
# count 26003.000 26495.000 28477.000 28107.000 30840.000 30554.000 30162.000
# mean      2.229     2.226     2.222     2.230     2.240     2.224     2.234
# std       0.733     0.732     0.731     0.735     0.743     0.739     0.740
# min       1.477     1.477     1.477     1.477     1.477     1.477     1.477
# 25%       1.602     1.602     1.602     1.602     1.602     1.602     1.602
# 50%       2.000     2.000     2.000     2.000     2.000     2.000     2.000
# 75%       2.633     2.633     2.633     2.643     2.653     2.623     2.643
# max       5.537     5.536     5.610     5.596     5.620     5.561     5.536
#
#           1950s     1960s     1970s     1980s         cf
# count 31315.000 30725.000 31638.000 33478.000 108894.000
# mean      2.230     2.240     2.232     2.234      2.229
# std       0.734     0.734     0.730     0.732      0.852
# min       1.477     1.477     1.477     1.477      1.477
# 25%       1.602     1.602     1.602     1.602      1.602
# 50%       2.000     2.041     2.000     2.000      1.954
# 75%       2.633     2.643     2.633     2.643      2.591
# max       5.544     5.541     5.525     5.488      6.726

# %% [markdown]
# From the description table above, we see how higher counts can be biased towards the importance of a term.
#
# Hence another transformation is performed - Raw frequencies to term frequencies.

# %%
pattern_counts=unigram.pattern.value_counts().to_frame()
pattern_counts['perc']=round((pattern_counts['pattern']/pattern_counts['pattern'].sum())*100,3)
pattern_counts.sort_index(inplace=True)
pattern_counts
# Out:
#                     pattern  perc
# 000000000000000001     6915 6.350
# 000000000000000010     4724 4.338
# 000000000000000011      975 0.895
# 000000000000000100     4251 3.904
# 000000000000000101      314 0.288
# 000000000000000110      367 0.337
# 000000000000000111      569 0.523
# 000000000000001000     4342 3.987
# 000000000000001001      269 0.247
# 000000000000001010      225 0.207
# 000000000000001011      179 0.164
# 000000000000001100      311 0.286
# 000000000000001101      123 0.113
# 000000000000001110      138 0.127
# 000000000000001111      470 0.432
# 000000000000010000     3843 3.529
# 000000000000010001      166 0.152
# 000000000000010010      146 0.134
# 000000000000010011       76 0.070
# 000000000000010100      148 0.136
# 000000000000010101       51 0.047
# 000000000000010110       52 0.048
# 000000000000010111      103 0.095
# 000000000000011000      292 0.268
# 000000000000011001       68 0.062
# 000000000000011010       49 0.045
# 000000000000011011       69 0.063
# 000000000000011100      102 0.094
# 000000000000011101       57 0.052
# 000000000000011110       63 0.058
# ...                     ...   ...
# 111111111111100000       12 0.011
# 111111111111100001        1 0.001
# 111111111111100010        1 0.001
# 111111111111100011        2 0.002
# 111111111111100100        1 0.001
# 111111111111100110        2 0.002
# 111111111111100111        1 0.001
# 111111111111101000        3 0.003
# 111111111111101001        1 0.001
# 111111111111101010        4 0.004
# 111111111111101011        1 0.001
# 111111111111101100        1 0.001
# 111111111111101110        2 0.002
# 111111111111101111        3 0.003
# 111111111111110000        7 0.006
# 111111111111110001        1 0.001
# 111111111111110010        2 0.002
# 111111111111110011        2 0.002
# 111111111111110100        5 0.005
# 111111111111110101        3 0.003
# 111111111111110110        3 0.003
# 111111111111110111        8 0.007
# 111111111111111000       10 0.009
# 111111111111111001        5 0.005
# 111111111111111010        9 0.008
# 111111111111111011       16 0.015
# 111111111111111100       11 0.010
# 111111111111111101       16 0.015
# 111111111111111110       26 0.024
# 111111111111111111     4967 4.561
#
# [9520 rows x 2 columns]

# %%
#xlabels=pattern_counts[pattern_counts.pattern>4000].index
#xlabels

# %%
pattern_counts.sort_values('perc', ascending=False).head(20).drop('perc',axis=1).plot.bar(figsize=(10,10))

# %%
#fig, ax = plt.subplots()
#pattern_counts.pattern.plot(ax=ax,figsize=(15,15),rot=45)
#tick_idx = plt.xticks()[0]
#year_labels = df.years[tick_idx].values
#ax.xaxis.set_ticklabels(xlabels)

#pattern_counts.pattern.plot(figsize=(15,15),xticks=xlabels)

# %%
pattern_counts.perc[pattern_counts.perc>=5.0].sum()
# Out:
# 6.35

# %% [markdown]
# From the table above we see that that log normalization has helped in reducing the variation of the terms across the decades.

# %% [markdown]
# There are still 357971 possible unigrams in the dataset, and that would mean we would theoritically 357971*357971 rows in the bigram dataset.
#
# It then makes sence to figure out ways of eliminating uni-grams that are less "informative".
#
# A unigram could be considered to be "informative" if it -
#
# 1. Occurs consistently across the decades. (Given by the presence column)
# 2. Has a good frequency accoess the decades. (Given by the cf column)
#
#
# Given below are graphs and more statistics that hopefully could help you in deciding the correct amount of unigrams that should be selected.

# %%
decade_presence=unigram.presence.value_counts().to_frame()
decade_presence['perc']=round((decade_presence.presence/decade_presence.presence.sum())*100,3)
decade_presence.sort_index(inplace=True)
decade_presence
# Out:
#     presence   perc
# 1      57433 52.742
# 2      12022 11.040
# 3       6374  5.853
# 4       4185  3.843
# 5       3281  3.013
# 6       2605  2.392
# 7       2232  2.050
# 8       1864  1.712
# 9       1707  1.568
# 10      1404  1.289
# 11      1266  1.163
# 12      1172  1.076
# 13      1088  0.999
# 14      1022  0.939
# 15      1234  1.133
# 16      1775  1.630
# 17      3263  2.996
# 18      4967  4.561

# %% [markdown]
# The table above and the plot below show how the proportion of words changes w.r.t the Presence column.

# %%
fig, ax = plt.subplots()
decade_presence.drop('presence',axis=1).plot.bar(ax=ax,figsize=(10,10))
plt.xlabel('Number of decades the unigram is present in', fontsize=18)
plt.ylabel('Proportion of words', fontsize=18)
plt.show()

# %% [markdown]
# What we could decipher from above is that several words only belong in 4 of fewer decades. Such words could be removed as they might be helpful in discovering future compounds.
#
# You could make a call on how important this statistic is.

# %%
fig, ax = plt.subplots()
unigram.drop('presence',axis=1).plot.box(ax=ax,showfliers=True,figsize=(20,15),legend =True,notch=True)

plt.xlabel('Decades', fontsize=18)
plt.ylabel('Frequency', fontsize=18)
plt.show()

# %% [markdown]
# From the boxplot of Decades vs. the Frequency of a unigram we can see the visual represention of the description of the unigram dataset.
#
# The cf (Collection Frequency) column encompasses the information of a unigram for all the decades, and hence should be useful in selecting the possible unigrams.

# %%
unigram.hist(figsize=(20,20),alpha=0.5,bins=20,normed=1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3960CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED39CFDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED39E09E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3C1D320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3C64518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3CB8630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3D016D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3D5E240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3DA7C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3DD5BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED2A690F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED2A9CA90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3D67128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED29F2F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED2DC4CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED2E0E3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED2E63278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED2EAC588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3E4B0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3EE38D0>]], dtype=object)

# %% [markdown]
# The histograms do not seem to highlight anything out of the blue.

# %% [markdown]
# The graphs below are maybe where Lonneke could give her perpective.
#
# Each individual graph shows how the Collection Frequency varies w.r.t the Presence column.

# %%
unigram.hist(by= 'presence',column ='cf', figsize=(20, 20),bins=50,sharex=True,log=True,sharey=True,normed=True,range=(1,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED3FAC828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4C82F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED56E3A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4E84390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4EB9240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4F0A0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4F49E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4FA85F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED4FF1EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED5020EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED508F860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED509CD68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED512A630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED5170588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED51C4400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED5210208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED526AA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED52B9278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED52E51D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015ED5350E48>]], dtype=object)

# %% [markdown]
# In both the Histograms and the Boxplots, following are observed -
#
# 1. The distribution of the cf spreads out (becomes more normal as well) as the presence of a unigram increases.
# 2. The median and the IQR (the region represented by the box in the bloxplot) keep shifting higher.

# %%
#fig, ax = plt.subplots()
unigram.boxplot(by= 'presence',column ='cf',figsize=(20, 20),notch=True)
#plt.figure(figsize=(20, 20))
#plt.axhline(y=2, color='r', linestyle='-')
#plt.xlabel('Presence', fontsize=18)
#plt.ylabel('Collection Frequency', fontsize=18)

#plt.show()

# %% [markdown]
# The boxplots could help you in deciding on the cutoff value for the collection frequency.
#
# For example, if you wish to select unigrams that have a collection frequency > 2 and have been seen in 4 or more decades, then you would the graph below.

# %%
fig, ax = plt.subplots()
unigram[['presence','cf']].boxplot(ax=ax,by= 'presence',figsize=(20,20),notch=True)
#plt.figure(figsize=(20, 20))
plt.axhline(y=2, color='r', linestyle='-')
plt.axvline(x=4.5,color='g',linestyle='-')
plt.xlabel('Presence', fontsize=10)
plt.ylabel('Collection Frequency', fontsize=10)

plt.show()

# %% [markdown]
# The fact that the distributions are changing should not too suprising, as it makes sence that the cf inscreases as the decades go by.

# %%
ax=unigram.groupby('presence')['cf'].mean().plot()
ax.set(xlabel="Presence", ylabel="Collection Frequency")
# Out:
# [<matplotlib.text.Text at 0x15edd4221d0>,
#  <matplotlib.text.Text at 0x15edd40b2e8>]

# %% [markdown]
# I hope all the above statistics helped you understand the complexity of the problem.
#
# Now, if we were to select a cut-off for the collection frequency value as we did before, we would get the new reduced dataset as below.

# %%
newunigram=unigram[((unigram.cf>2.0)==True)  & (unigram.presence.isin([1,2,3,4])==False)]
newunigram
# Out:
#                 1810s  1820s  1830s  1840s  1850s  1860s  1870s  1880s  1890s  \
# word
# a'ready_noun      nan    nan  1.602  1.602  1.954  1.602  1.477  2.230  1.477
# a-bomb_noun       nan    nan    nan    nan    nan    nan    nan    nan    nan
# a-callin_noun     nan    nan    nan    nan    nan    nan  1.602  1.477    nan
# a-cryin_noun      nan    nan    nan    nan    nan    nan  1.477    nan  1.845
# a-fishing_noun    nan    nan    nan  1.699  2.114  2.000  1.778  1.845  2.041
# a-gettin_noun     nan    nan    nan    nan    nan    nan    nan  1.477  1.845
# a-gittin_noun     nan    nan    nan    nan    nan    nan  1.845  1.903  2.176
# a-hangin_noun     nan    nan    nan    nan    nan    nan  1.477  1.954  1.778
# a-huntin_noun     nan    nan    nan    nan    nan    nan  1.845  1.699    nan
# a-hunting_noun    nan    nan    nan    nan    nan    nan    nan    nan  2.146
# a-i_noun          nan    nan    nan    nan    nan    nan    nan    nan    nan
# a-layin_noun      nan    nan    nan    nan    nan    nan  1.477  2.000  2.041
# a-livin_noun      nan    nan    nan    nan    nan    nan  1.477  1.602  1.602
# a-lookin_noun     nan    nan    nan    nan    nan  1.477  2.279  1.954  2.204
# a-purpose_noun    nan    nan    nan  1.477    nan  1.477    nan    nan  1.778
# a-ridin_noun      nan    nan    nan    nan    nan    nan  1.602  1.602    nan
# a-runnin_noun     nan    nan    nan    nan    nan    nan  1.477  1.778  2.176
# a-sayin_noun      nan    nan    nan    nan    nan  1.477  1.845  1.903  2.114
# a-settin_noun     nan    nan    nan    nan    nan    nan  1.954  2.322  2.301
# a-singin_noun     nan    nan    nan    nan    nan    nan    nan  1.699  1.699
# a-standin_noun    nan    nan    nan    nan    nan    nan  1.602  1.602  1.778
# a-tellin_noun     nan    nan    nan    nan    nan    nan    nan  1.845  1.778
# a-thinkin_noun    nan    nan    nan    nan    nan    nan  2.041  1.954  1.954
# a-waitin_noun     nan    nan    nan    nan    nan  1.699  1.954  2.176  1.954
# a-watchin_noun    nan    nan    nan    nan    nan  1.477  1.602    nan  2.114
# a-workin_noun     nan    nan    nan    nan    nan    nan  1.477    nan  1.954
# a_noun            nan    nan    nan    nan    nan  3.190  2.301  3.354  2.580
# aar_noun          nan    nan  1.602    nan  1.699  1.699    nan    nan    nan
# ab_noun           nan    nan  2.204  2.398  2.230  2.176  2.255  2.041  1.699
# aba_noun          nan    nan    nan    nan    nan  1.477    nan    nan    nan
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# zest_noun         nan  2.279  2.580  2.771  2.857  2.857  3.029  3.029  3.093
# zeta_noun         nan    nan    nan    nan    nan    nan    nan    nan  1.477
# zey_noun          nan    nan    nan    nan  1.954    nan    nan  1.602    nan
# ziegfeld_noun     nan    nan    nan    nan    nan    nan    nan    nan    nan
# zigzag_noun       nan    nan  2.279  2.204  2.763  2.462  2.580  2.491  2.505
# zimmerman_noun    nan    nan  1.602    nan    nan    nan    nan    nan    nan
# zinc_noun         nan    nan  1.778  2.826  2.544  2.204  2.301  2.623  2.954
# zing_noun         nan    nan    nan    nan    nan  1.602    nan    nan    nan
# zinnia_noun       nan    nan    nan    nan    nan    nan    nan    nan    nan
# zionism_noun      nan    nan    nan    nan    nan    nan    nan    nan    nan
# zionist_noun      nan    nan    nan    nan    nan    nan    nan    nan    nan
# zip_noun          nan    nan    nan    nan    nan  1.477  1.477    nan  1.477
# zipper_noun       nan    nan    nan    nan    nan    nan    nan    nan    nan
# zis_noun          nan    nan    nan    nan  1.699  2.176  2.279  1.845  1.477
# zither_noun       nan    nan    nan    nan    nan    nan    nan  1.602  1.477
# zo_noun           nan  2.708  1.602    nan  1.477    nan    nan  1.699  1.477
# zodiac_noun       nan    nan  2.079  2.204  2.146  1.778  2.146  2.230  2.204
# zombie_noun       nan    nan    nan    nan    nan    nan    nan    nan    nan
# zone_noun       1.699  2.447  3.009  3.340  3.021  3.134  2.908  3.188  3.173
# zoning_noun       nan    nan    nan    nan    nan    nan    nan    nan    nan
# zoo_noun          nan    nan    nan    nan    nan    nan    nan  1.477  1.903
# zoologist_noun    nan    nan  1.477    nan  2.079  2.000  2.146  1.845  2.398
# zoology_noun      nan    nan  1.602  2.301  2.380  1.778  2.477  2.176  1.954
# zoom_noun         nan    nan    nan    nan    nan    nan    nan    nan    nan
# zoophyte_noun     nan    nan  1.699  2.279  2.204    nan  2.079  1.602  1.602
# zoroaster_noun    nan    nan  1.477    nan    nan    nan  1.699    nan  1.903
# zouaves_noun      nan    nan    nan    nan    nan  2.505  1.845  2.114  1.699
# zulu_noun         nan    nan    nan    nan    nan    nan  2.176  1.845  2.041
# zum_noun          nan  1.602    nan    nan    nan    nan    nan    nan  1.602
# zuni_noun         nan    nan    nan    nan    nan    nan    nan  2.000  1.903
#
#                 1900s         ...          1920s  1930s  1940s  1950s  1960s  \
# word                          ...
# a'ready_noun    2.114         ...          1.477  1.954  1.778    nan    nan
# a-bomb_noun       nan         ...            nan    nan  1.845  2.771  2.322
# a-callin_noun   1.477         ...            nan  1.477    nan    nan    nan
# a-cryin_noun      nan         ...            nan  1.845  1.477    nan    nan
# a-fishing_noun  2.041         ...          2.000    nan    nan    nan    nan
# a-gettin_noun   1.477         ...            nan  1.778  2.176  2.230    nan
# a-gittin_noun   1.845         ...          2.041    nan  2.041    nan    nan
# a-hangin_noun     nan         ...            nan    nan    nan  1.778    nan
# a-huntin_noun   2.000         ...          1.699    nan    nan  1.954    nan
# a-hunting_noun  1.602         ...          1.778  1.602    nan    nan    nan
# a-i_noun          nan         ...            nan  1.477  1.602  1.778  1.699
# a-layin_noun    1.903         ...            nan  1.477    nan  1.845    nan
# a-livin_noun      nan         ...            nan    nan  1.778  1.903    nan
# a-lookin_noun   2.041         ...          1.954  1.477  2.230  1.778    nan
# a-purpose_noun  1.903         ...          1.903    nan  1.903    nan    nan
# a-ridin_noun    1.778         ...          1.477    nan    nan    nan    nan
# a-runnin_noun   2.000         ...          2.146  1.699  2.176  2.230    nan
# a-sayin_noun    1.699         ...          2.146  1.602  2.146  1.602    nan
# a-settin_noun   2.041         ...          2.114  1.778  2.079  1.477    nan
# a-singin_noun   1.602         ...          1.699    nan  1.602    nan    nan
# a-standin_noun  1.602         ...          1.699  1.602  1.954  1.954    nan
# a-tellin_noun   1.778         ...          1.699  1.602  2.204  1.699    nan
# a-thinkin_noun  1.845         ...          1.778  1.477  2.204  1.845    nan
# a-waitin_noun   2.000         ...          1.602    nan  1.699  1.602    nan
# a-watchin_noun  1.778         ...            nan  1.477    nan    nan    nan
# a-workin_noun   1.845         ...          1.699  1.845  1.778    nan    nan
# a_noun          2.505         ...          2.176    nan  1.699    nan    nan
# aar_noun          nan         ...          1.699  1.602  1.903    nan    nan
# ab_noun         2.114         ...          2.380  2.301    nan  1.845  1.903
# aba_noun          nan         ...            nan  1.477  2.000  1.477    nan
# ...               ...         ...            ...    ...    ...    ...    ...
# zest_noun       3.025         ...          3.182  2.940  2.914  2.940  2.785
# zeta_noun       1.477         ...          1.699  1.954  2.000  1.778  2.255
# zey_noun        2.204         ...            nan  1.699  1.477    nan    nan
# ziegfeld_noun     nan         ...          2.362  2.146  2.079  2.041  2.041
# zigzag_noun     2.580         ...          2.556  2.544  2.580  2.623  2.301
# zimmerman_noun    nan         ...          1.845  2.544    nan  1.699  2.447
# zinc_noun       2.944         ...          3.164  3.158  3.033  3.061  2.908
# zing_noun         nan         ...          1.602  1.477  1.477  1.602  1.954
# zinnia_noun       nan         ...            nan  2.230  2.041  2.255  2.255
# zionism_noun      nan         ...          1.903  2.724  2.176  2.176  2.255
# zionist_noun      nan         ...          2.477  2.806  2.602  2.362  2.431
# zip_noun        1.778         ...          1.778  2.041  2.255  2.301  2.663
# zipper_noun       nan         ...            nan  2.398  2.415  2.613  2.732
# zis_noun        2.301         ...            nan  2.613    nan  1.778    nan
# zither_noun     1.602         ...          1.477  2.204  1.778  1.954    nan
# zo_noun         2.477         ...          2.447  1.778  2.041  2.301  2.602
# zodiac_noun     2.146         ...          2.477  2.079  2.176  1.699  2.041
# zombie_noun       nan         ...            nan    nan  2.301  2.176  2.398
# zone_noun       3.486         ...          3.579  3.710  3.945  3.930  3.823
# zoning_noun       nan         ...          2.415  2.477  2.362  2.785  3.076
# zoo_noun        2.875         ...          3.117  3.204  3.127  3.423  3.334
# zoologist_noun  2.362         ...          2.114  2.255  2.477  2.176  2.301
# zoology_noun    2.505         ...          2.176  2.176  2.380  2.342  2.176
# zoom_noun         nan         ...          1.477  2.000  2.041  1.477  2.000
# zoophyte_noun     nan         ...            nan    nan    nan    nan    nan
# zoroaster_noun    nan         ...            nan    nan    nan  1.778    nan
# zouaves_noun    1.477         ...            nan  1.602  1.778    nan    nan
# zulu_noun       2.342         ...          1.903  2.204  2.255  2.398  2.279
# zum_noun          nan         ...            nan  1.477  1.699  1.602  2.279
# zuni_noun       1.477         ...          1.903  1.602  1.903    nan    nan
#
#                 1970s  1980s    cf  presence             pattern
# word
# a'ready_noun      nan    nan 2.954        12  001111111111110000
# a-bomb_noun     2.000  2.204 3.053         5  000000000000011111
# a-callin_noun     nan    nan 2.230         5  000000110110100000
# a-cryin_noun      nan    nan 2.380         5  000000101010110000
# a-fishing_noun    nan    nan 2.898         9  000111111111000000
# a-gettin_noun     nan  1.903 2.792         8  000000011110111001
# a-gittin_noun     nan    nan 2.792         7  000000111111010000
# a-hangin_noun     nan    nan 2.447         5  000000111010001000
# a-huntin_noun     nan    nan 2.556         5  000000110101001000
# a-hunting_noun    nan    nan 2.505         5  000000001111100000
# a-i_noun          nan  1.602 2.342         5  000000000000111101
# a-layin_noun      nan    nan 2.623         6  000000111100101000
# a-livin_noun      nan    nan 2.398         5  000000111000011000
# a-lookin_noun     nan    nan 3.025        10  000001111111111000
# a-purpose_noun  1.699  1.699 2.716         9  000101001111010011
# a-ridin_noun      nan    nan 2.491         5  000000110111000000
# a-runnin_noun     nan    nan 2.959         9  000000111111111000
# a-sayin_noun      nan    nan 2.886        10  000001111111111000
# a-settin_noun     nan    nan 3.013         9  000000111111111000
# a-singin_noun     nan    nan 2.431         6  000000011111010000
# a-standin_noun    nan    nan 2.716         9  000000111111111000
# a-tellin_noun   1.602    nan 2.763         9  000000011111111010
# a-thinkin_noun    nan    nan 2.875         9  000000111111111000
# a-waitin_noun     nan    nan 2.845         9  000001111111011000
# a-watchin_noun    nan    nan 2.531         6  000001101110100000
# a-workin_noun     nan    nan 2.568         6  000000101101110000
# a_noun            nan    nan 3.691         7  000001111101010000
# aar_noun          nan    nan 2.531         7  001011000011110000
# ab_noun         2.079  1.954 3.316        15  001111111111101111
# aba_noun        2.519  2.431 2.898         6  000001000000111011
# ...               ...    ...   ...       ...                 ...
# zest_noun       2.799  2.763 4.151        17  011111111111111111
# zeta_noun       2.362  1.602 2.908         9  000000001101111111
# zey_noun          nan    nan 2.732         6  000010010110110000
# ziegfeld_noun   1.903  1.903 2.940         7  000000000001111111
# zigzag_noun     2.556  2.544 3.745        16  001111111111111111
# zimmerman_noun    nan    nan 2.914         6  001000000011101100
# zinc_noun       2.839  2.908 4.081        16  001111111111111111
# zing_noun       1.903  1.903 2.681         9  000001000011111111
# zinnia_noun     2.079  1.845 2.982         7  000000000010111111
# zionism_noun    3.037  2.813 3.459         8  000000000011111111
# zionist_noun    2.763  2.898 3.516         8  000000000011111111
# zip_noun        2.415  2.996 3.393        12  000001101111111111
# zipper_noun     2.845  2.806 3.447         6  000000000000111111
# zis_noun        1.477  1.903 3.127        11  000011111110101011
# zither_noun     1.602    nan 2.716         9  000000011111111010
# zo_noun         2.301  1.602 3.371        14  011010011111111111
# zodiac_noun     2.342  2.079 3.340        16  001111111111111111
# zombie_noun     2.806  2.813 3.276         5  000000000000011111
# zone_noun       3.752  3.901 4.805        18  111111111111111111
# zoning_noun     3.146  2.716 3.657         8  000000000011111111
# zoo_noun        3.587  3.377 4.218        11  000000011111111111
# zoologist_noun  2.176  1.778 3.358        15  001011111111111111
# zoology_noun    2.431  2.041 3.462        16  001111111111111111
# zoom_noun       2.255  2.279 2.869         7  000000000001111111
# zoophyte_noun     nan    nan 2.778         6  001110111000000000
# zoroaster_noun    nan  1.845 2.519         6  001000101010001001
# zouaves_noun      nan  1.477 2.863         8  000001111100110001
# zulu_noun       2.230  2.892 3.391        12  000000111111111111
# zum_noun          nan    nan 2.633         7  010000001010111100
# zuni_noun         nan    nan 2.613         6  000000011101110000
#
# [28880 rows x 21 columns]

# %%
pattern_counts=newunigram.pattern.value_counts().to_frame()
pattern_counts['perc']=round((pattern_counts['pattern']/pattern_counts['pattern'].sum())*100,3)
pattern_counts.sort_index(inplace=True)
pattern_counts
# Out:
#                     pattern   perc
# 000000000000011111      474  1.641
# 000000000000101111      108  0.374
# 000000000000110111       41  0.142
# 000000000000111011       40  0.139
# 000000000000111101       47  0.163
# 000000000000111110       56  0.194
# 000000000000111111      492  1.704
# 000000000001001111       40  0.139
# 000000000001010111       16  0.055
# 000000000001011011       16  0.055
# 000000000001011101       13  0.045
# 000000000001011110       13  0.045
# 000000000001011111       87  0.301
# 000000000001100111       16  0.055
# 000000000001101011        8  0.028
# 000000000001101101       14  0.048
# 000000000001101110       14  0.048
# 000000000001101111       38  0.132
# 000000000001110011       15  0.052
# 000000000001110101        9  0.031
# 000000000001110110       15  0.052
# 000000000001110111       23  0.080
# 000000000001111001       14  0.048
# 000000000001111010       15  0.052
# 000000000001111011       31  0.107
# 000000000001111100       33  0.114
# 000000000001111101       23  0.080
# 000000000001111110       35  0.121
# 000000000001111111      438  1.517
# 000000000010001111        9  0.031
# ...                     ...    ...
# 111111111111100000       12  0.042
# 111111111111100001        1  0.003
# 111111111111100010        1  0.003
# 111111111111100011        2  0.007
# 111111111111100100        1  0.003
# 111111111111100110        2  0.007
# 111111111111100111        1  0.003
# 111111111111101000        3  0.010
# 111111111111101001        1  0.003
# 111111111111101010        4  0.014
# 111111111111101011        1  0.003
# 111111111111101100        1  0.003
# 111111111111101110        2  0.007
# 111111111111101111        3  0.010
# 111111111111110000        7  0.024
# 111111111111110001        1  0.003
# 111111111111110010        2  0.007
# 111111111111110011        2  0.007
# 111111111111110100        5  0.017
# 111111111111110101        3  0.010
# 111111111111110110        3  0.010
# 111111111111110111        8  0.028
# 111111111111111000       10  0.035
# 111111111111111001        5  0.017
# 111111111111111010        9  0.031
# 111111111111111011       16  0.055
# 111111111111111100       11  0.038
# 111111111111111101       16  0.055
# 111111111111111110       26  0.090
# 111111111111111111     4967 17.199
#
# [7554 rows x 2 columns]

# %%
pattern_counts.sort_values('perc', ascending=False).head(20).drop('perc',axis=1).plot.bar()

# %% [markdown]
# As you can see, the dataset is reduced to 1/3rd its original size.
#
# We, however are still left with unsuitable unigrams such as "a-blaze_adj", "a'mighty_noun",etc.
#
# You can access all the unigrams in the dataset using the code below (they are grouped by the first letter of the unigram)

# %%
unigram_list=newunigram.index.tolist()
unigram_dict={}
for letter, words in groupby(sorted(unigram_list), key=itemgetter(0)):
    #print(letter)
    for word in words:
        if letter not in unigram_dict:
            unigram_dict[letter]=list()
            unigram_dict[letter].append(word)
        else:
            unigram_dict[letter].append(word)

# %%
for letter in unigram_dict:
    print("There are ",len(unigram_dict[letter]),"terms with the letter ", letter)
# Out:
# There are  254 terms with the letter  k
# There are  307 terms with the letter  j
# There are  1059 terms with the letter  g
# There are  52 terms with the letter  z
# There are  2973 terms with the letter  c
# There are  582 terms with the letter  n
# There are  979 terms with the letter  e
# There are  1350 terms with the letter  r
# There are  616 terms with the letter  o
# There are  963 terms with the letter  i
# There are  1568 terms with the letter  a
# There are  953 terms with the letter  w
# There are  1817 terms with the letter  b
# There are  1555 terms with the letter  d
# There are  123 terms with the letter  y
# There are  132 terms with the letter  q
# There are  3528 terms with the letter  s
# There are  1267 terms with the letter  h
# There are  1626 terms with the letter  t
# There are  448 terms with the letter  v
# There are  14 terms with the letter  x
# There are  314 terms with the letter  u
# There are  2321 terms with the letter  p
# There are  1061 terms with the letter  l
# There are  1643 terms with the letter  m
# There are  1375 terms with the letter  f

# %% [markdown]
# You could now try to look through these terms and if any outliers exist.
#
# For example, if we look at  some unigrams that start with a 'b' we see there exist outliers which -
#
# 1. Have symbols in between the words (b'nai_noun,b'y_noun) . These must be errors in reading the documents during OCR step
# 2. Are already compounds (baby-blue_adj,baby-clothes_noun,back-and-forth_adj).
#
#
#
#
# I hope all of the above steps and explained helped you in understanding the task.
#
# So, to reiterate your task would be to remove of unwanted unigrams that are present in the dataset.
# They could be due
# 1. Errors during scanning of the document,
# 2. Unigrams that are not in fact, unigrams
# 3. Unigrams that occur too infrequently and/or in too few decades

# %%
unigram_dict['b']
# Out:
# ["b'ar_noun",
#  "b'ilin_noun",
#  "b'lieve_noun",
#  "b'y_noun",
#  "b'ys_noun",
#  'ba_noun',
#  'babble_noun',
#  'babbler_noun',
#  'babbling_noun',
#  'babby_noun',
#  'babcock_noun',
#  'babe_noun',
#  'babel_noun',
#  'babette_noun',
#  'baboon_noun',
#  'baby-house_noun',
#  'baby-sitter_noun',
#  'baby-talk_noun',
#  'baby_noun',
#  'babyhood_noun',
#  'babylon_noun',
#  'babylonian_noun',
#  'bac_noun',
#  'bacardi_noun',
#  'baccarat_noun',
#  'bacchant_noun',
#  'bacco_noun',
#  'bach_noun',
#  'bache_noun',
#  'bachelor_noun',
#  'bachelorhood_noun',
#  'bacillus_noun',
#  'back-bone_noun',
#  'back-door_noun',
#  'back-ground_noun',
#  'back-log_noun',
#  'back-stairs_noun',
#  'back-yard_noun',
#  'back_noun',
#  'backache_noun',
#  'backboard_noun',
#  'backbone_noun',
#  'backcourt_noun',
#  'backdoor_noun',
#  'backdrop_noun',
#  'backer_noun',
#  'backfield_noun',
#  'backgammon_noun',
#  'background_noun',
#  'backin_noun',
#  'backing_noun',
#  'backlash_noun',
#  'backlog_noun',
#  'backroom_noun',
#  'backside_noun',
#  'backslider_noun',
#  'backsliding_noun',
#  'backstairs_noun',
#  'backstop_noun',
#  'backstretch_noun',
#  'backstroke_noun',
#  'backwardness_noun',
#  'backwash_noun',
#  'backwater_noun',
#  'backwoods_noun',
#  'backwoodsman_noun',
#  'backyard_noun',
#  'bacon_noun',
#  'bacteria_noun',
#  'bacteriologist_noun',
#  'bacteriology_noun',
#  'bacterium_noun',
#  'bad_noun',
#  'badge_noun',
#  'badger_noun',
#  'badinage_noun',
#  'badlands_noun',
#  'badminton_noun',
#  'badness_noun',
#  'baedeker_noun',
#  'baffle_noun',
#  'bafflement_noun',
#  'bag_noun',
#  'bagatelle_noun',
#  'bagdad_noun',
#  'baggage-master_noun',
#  'baggage_noun',
#  'baggageman_noun',
#  'bagman_noun',
#  'bagpipe_noun',
#  'bahai_noun',
#  'bail_noun',
#  'bailey_noun',
#  'bailiff_noun',
#  'bailiwick_noun',
#  'bairn_noun',
#  'bait_noun',
#  'baith_noun',
#  'baiting_noun',
#  'baize_noun',
#  'bakehouse_noun',
#  'baker_noun',
#  'bakery_noun',
#  'bakeshop_noun',
#  'bakin_noun',
#  'baking_noun',
#  'bal_noun',
#  'balaam_noun',
#  'balaclava_noun',
#  'balance-sheet_noun',
#  'balance-wheel_noun',
#  'balance_noun',
#  'balancing_noun',
#  'balcony_noun',
#  'bald-headed_noun',
#  'balderdash_noun',
#  'baldness_noun',
#  'baldy_noun',
#  'bale_noun',
#  'baler_noun',
#  'baling_noun',
#  'balk_noun',
#  'balkan_noun',
#  'ball-dress_noun',
#  'ball-room_noun',
#  'ball-rooms_noun',
#  'ball_noun',
#  'ballad_noun',
#  'balladry_noun',
#  'ballast_noun',
#  'ballerina_noun',
#  'ballet-dancer_noun',
#  'ballet_noun',
#  'ballistics_noun',
#  'balloon_noun',
#  'balloonist_noun',
#  'ballot-box_noun',
#  'ballot-boxes_noun',
#  'ballot_noun',
#  'balloting_noun',
#  'ballpark_noun',
#  'ballplayer_noun',
#  'ballroom_noun',
#  'ballyhoo_noun',
#  'balm_noun',
#  'baloney_noun',
#  'balsa_noun',
#  'balsam_noun',
#  'baluster_noun',
#  'balustrade_noun',
#  'balzac_noun',
#  'bamboo_noun',
#  'ban_noun',
#  'banality_noun',
#  'banana_noun',
#  'bancroft_noun',
#  'band-aids_noun',
#  'band_noun',
#  'bandage_noun',
#  'bandana_noun',
#  'bandanna_noun',
#  'bandbox_noun',
#  'bandeau_noun',
#  'banding_noun',
#  'bandit_noun',
#  'banditry_noun',
#  'bandleader_noun',
#  'bandmaster_noun',
#  'bandolier_noun',
#  'bandsman_noun',
#  'bandstand_noun',
#  'bandwagon_noun',
#  'bane_noun',
#  'bang-up_noun',
#  'bang_noun',
#  'banging_noun',
#  'bangle_noun',
#  'banian_noun',
#  'banishment_noun',
#  'banister_noun',
#  'banjo_noun',
#  'bank-bills_noun',
#  'bank-book_noun',
#  'bank-note_noun',
#  'bank-notes_noun',
#  'bank_noun',
#  'bankbook_noun',
#  'banker_noun',
#  'banking-house_noun',
#  'banking_noun',
#  'banknote_noun',
#  'bankroll_noun',
#  'bankrupt_noun',
#  'bankruptcy_noun',
#  'banner_noun',
#  'bannerman_noun',
#  'banning_noun',
#  'bannister_noun',
#  'bannock_noun',
#  'banns_noun',
#  'banquet_noun',
#  'banqueters_noun',
#  'banquette_noun',
#  'banshee_noun',
#  'bantam_noun',
#  'bantamweight_noun',
#  'banter_noun',
#  'bantering_noun',
#  'banyan_noun',
#  'banzai_noun',
#  'baobab_noun',
#  'baptism_noun',
#  'baptist_noun',
#  'baptiste_noun',
#  'baptistery_noun',
#  "bar'l_noun",
#  'bar-keeper_noun',
#  'bar-room_noun',
#  'bar-rooms_noun',
#  'bar_noun',
#  'barabbas_noun',
#  'barb_noun',
#  'barbadoes_noun',
#  'barbarian_noun',
#  'barbarism_noun',
#  'barbarity_noun',
#  'barbecue_noun',
#  'barbell_noun',
#  'barber-shop_noun',
#  'barber_noun',
#  'barberry_noun',
#  'barbershop_noun',
#  'barbiturate_noun',
#  'bard_noun',
#  'bare-headed_noun',
#  'bareness_noun',
#  'bargain_noun',
#  'bargainer_noun',
#  'bargaining_noun',
#  'barge_noun',
#  'bargeman_noun',
#  'baritone_noun',
#  'barium_noun',
#  'bark_noun',
#  'barkeep_noun',
#  'barkeeper_noun',
#  'barker_noun',
#  'barkin_noun',
#  'barking_noun',
#  'barley_noun',
#  'barmaid_noun',
#  'barman_noun',
#  'barn-door_noun',
#  'barn-yard_noun',
#  'barn_noun',
#  'barnacle_noun',
#  'barnard_noun',
#  'barnum_noun',
#  'barnyard_noun',
#  'barometer_noun',
#  'baron_noun',
#  'baroness_noun',
#  'baronet_noun',
#  'baronetcy_noun',
#  'barony_noun',
#  'baroque_noun',
#  'barouche_noun',
#  'barque_noun',
#  'barrack_noun',
#  'barracuda_noun',
#  'barrage_noun',
#  'barrel_noun',
#  'barren_noun',
#  'barrenness_noun',
#  'barricade_noun',
#  'barrier_noun',
#  'barrin_noun',
#  'barrister_noun',
#  'barron_noun',
#  'barroom_noun',
#  'barrow_noun',
#  'barstow_noun',
#  'bart_noun',
#  'bartender_noun',
#  'barter_noun',
#  'bartering_noun',
#  'bartram_noun',
#  'baruch_noun',
#  'barytone_noun',
#  'bas-relief_noun',
#  'bas-reliefs_noun',
#  'basalt_noun',
#  'base-ball_noun',
#  'base_noun',
#  'baseball_noun',
#  'baseboard_noun',
#  'baseline_noun',
#  'baseman_noun',
#  'basemen_noun',
#  'basement_noun',
#  'baseness_noun',
#  'bash_noun',
#  'bashaw_noun',
#  'bashfulness_noun',
#  'basic_noun',
#  'basil_noun',
#  'basilica_noun',
#  'basilisk_noun',
#  'basin_noun',
#  'basis_noun',
#  'basket-maker_noun',
#  'basket_noun',
#  'basketball_noun',
#  'basketful_noun',
#  'basketry_noun',
#  'basque_noun',
#  'bass-drum_noun',
#  'bass_noun',
#  'basset_noun',
#  'bassinet_noun',
#  'basso_noun',
#  'bassoon_noun',
#  'basswood_noun',
#  'bast_noun',
#  'basta_noun',
#  'bastard_noun',
#  'bastardy_noun',
#  'bastille_noun',
#  'bastinado_noun',
#  'basting_noun',
#  'bastion_noun',
#  'bat_noun',
#  'batch_noun',
#  'bate_noun',
#  'bateau_noun',
#  'bateaux_noun',
#  'bath-house_noun',
#  'bath-room_noun',
#  'bath-rooms_noun',
#  'bath-tub_noun',
#  'bath-tubs_noun',
#  'bath_noun',
#  'bather_noun',
#  'bathhouse_noun',
#  'bathing_noun',
#  'bathos_noun',
#  'bathrobe_noun',
#  'bathroom_noun',
#  'bathtub_noun',
#  'batik_noun',
#  'batiste_noun',
#  'baton_noun',
#  'batrachian_noun',
#  'batsman_noun',
#  'battalion_noun',
#  'batteau_noun',
#  'batten_noun',
#  'batter_noun',
#  'battering-ram_noun',
#  'battering_noun',
#  'battery_noun',
#  'batting_noun',
#  'battle-ax_noun',
#  'battle-axe_noun',
#  'battle-cry_noun',
#  'battle-field_noun',
#  'battle-fields_noun',
#  'battle-flag_noun',
#  'battle-ground_noun',
#  'battle-line_noun',
#  'battle-pieces_noun',
#  'battle-ships_noun',
#  'battle_noun',
#  'battledore_noun',
#  'battlefield_noun',
#  'battlefront_noun',
#  'battleground_noun',
#  'battlement_noun',
#  'battler_noun',
#  'battleship_noun',
#  'bauble_noun',
#  'baud_noun',
#  'bauxite_noun',
#  'bavarian_noun',
#  'bave_noun',
#  'bawd_noun',
#  'bawl_noun',
#  'bawlin_noun',
#  'bawling_noun',
#  'bawn_noun',
#  'bay-window_noun',
#  'bay_noun',
#  'bayard_noun',
#  'bayberry_noun',
#  'bayeux_noun',
#  'baying_noun',
#  'baylor_noun',
#  'bayonet_noun',
#  'bayou_noun',
#  'bayreuth_noun',
#  'bazaar_noun',
#  'bazar_noun',
#  'bazooka_noun',
#  "be'n_noun",
#  'be_noun',
#  'bea_noun',
#  'beach_noun',
#  'beachcomber_noun',
#  'beachhead_noun',
#  'beacon-light_noun',
#  'beacon_noun',
#  'bead_noun',
#  'beading_noun',
#  'beadle_noun',
#  'beadwork_noun',
#  'beagle_noun',
#  'beak_noun',
#  'beaker_noun',
#  'beam-ends_noun',
#  'beam_noun',
#  'bean_noun',
#  'beanstalk_noun',
#  'bear-skin_noun',
#  'bear_noun',
#  'beard_noun',
#  'bearer_noun',
#  'bearin_noun',
#  'bearing_noun',
#  'bearskin_noun',
#  'beast_noun',
#  'beastie_noun',
#  'beastliness_noun',
#  'beat-up_noun',
#  'beat_noun',
#  'beater_noun',
#  'beatification_noun',
#  'beatin_noun',
#  'beating_noun',
#  'beatitude_noun',
#  'beau_noun',
#  'beauregard_noun',
#  'beaut_noun',
#  'beautician_noun',
#  'beautification_noun',
#  'beauty_noun',
#  'beaux-arts_noun',
#  'beaver_noun',
#  'beaverboard_noun',
#  'bebop_noun',
#  'becausethe_noun',
#  'beck_noun',
#  'beckoning_noun',
#  'become_noun',
#  'becomea_noun',
#  'becomin_noun',
#  'bed-chamber_noun',
#  'bed-clothes_noun',
#  'bed-post_noun',
#  'bed-quilt_noun',
#  'bed-rock_noun',
#  'bed-room_noun',
#  'bed-rooms_noun',
#  'bed-side_noun',
#  'bed_noun',
#  'bedad_noun',
#  'bedbug_noun',
#  'bedchamber_noun',
#  'bedclothes_noun',
#  'bedcover_noun',
#  'bedding_noun',
#  'bedfellow_noun',
#  'bedlam_noun',
#  'bedlamite_noun',
#  'bedouin_noun',
#  'bedpan_noun',
#  'bedpost_noun',
#  'bedridden_noun',
#  'bedrock_noun',
#  'bedroll_noun',
#  'bedroom_noun',
#  'bedsheets_noun',
#  'bedside_noun',
#  'bedspread_noun',
#  'bedspring_noun',
#  'bedstead_noun',
#  'bee-hive_noun',
#  'bee-hives_noun',
#  'bee-line_noun',
#  'bee_noun',
#  'beea_noun',
#  'beech-tree_noun',
#  'beech-trees_noun',
#  'beech_noun',
#  'beecher_noun',
#  'beechnut_noun',
#  'beechwood_noun',
#  'beef-tea_noun',
#  'beef_noun',
#  'beefsteak_noun',
#  'beeg_noun',
#  'beehive_noun',
#  'beekeeper_noun',
#  'beekeeping_noun',
#  'beeline_noun',
#  'been_noun',
#  'beene_noun',
#  'beep_noun',
#  'beer_noun',
#  'beeswax_noun',
#  'beet_noun',
#  'beetle_noun',
#  'befall_noun',
#  'befo_noun',
#  'befor_noun',
#  'before_noun',
#  'beforeshe_noun',
#  'begat_noun',
#  'begets_noun',
#  'begetter_noun',
#  'beggar_noun',
#  'beggary_noun',
#  'beggin_noun',
#  'begging_noun',
#  'beginner_noun',
#  'beginnin_noun',
#  'beginning_noun',
#  'begone_noun',
#  'begonia_noun',
#  'begorra_noun',
#  'begot_noun',
#  'beguilement_noun',
#  'behalf_noun',
#  'behavior_noun',
#  'behaviorism_noun',
#  'behaviorist_noun',
#  'behaviour_noun',
#  'behead_noun',
#  'beheading_noun',
#  'behemoth_noun',
#  'behest_noun',
#  'behin_noun',
#  'behind_noun',
#  'beholder_noun',
#  'behoof_noun',
#  'bei_noun',
#  'beige_noun',
#  'bein_noun',
#  'being_noun',
#  'bejesus_noun',
#  'bel_noun',
#  'belabor_noun',
#  'belch_noun',
#  'beldame_noun',
#  'belden_noun',
#  'belfry_noun',
#  'belgian_noun',
#  'belief_noun',
#  'believer_noun',
#  'believin_noun',
#  'belknap_noun',
#  'bell-boy_noun',
#  'bell-rope_noun',
#  'bell_noun',
#  'bella_noun',
#  'belladonna_noun',
#  'bellboy_noun',
#  'belle_noun',
#  'belles-lettres_noun',
#  'bellevue_noun',
#  'bellhop_noun',
#  'belli_noun',
#  'belligerence_noun',
#  'belligerency_noun',
#  'belligerent_noun',
#  'bellini_noun',
#  'bellman_noun',
#  'bellow_noun',
#  'bellowing_noun',
#  'belly_noun',
#  'bellyache_noun',
#  'bellyful_noun',
#  'belongin_noun',
#  'belonging_noun',
#  'beloved_noun',
#  'belt_noun',
#  'belvidere_noun',
#  'bemis_noun',
#  'bemusement_noun',
#  'bench_noun',
#  'bend_noun',
#  'bender_noun',
#  'bendin_noun',
#  'bending_noun',
#  'bendix_noun',
#  'bene_noun',
#  'benedicite_noun',
#  'benedictine_noun',
#  'benediction_noun',
#  'benefaction_noun',
#  'benefactor_noun',
#  'benefactress_noun',
#  'benefice_noun',
#  'beneficence_noun',
#  'beneficiary_noun',
#  'benefit_noun',
#  'benevolence_noun',
#  'bengali_noun',
#  'benignant_noun',
#  'benignity_noun',
#  'benison_noun',
#  'benito_noun',
#  'benjy_noun',
#  'bennie_noun',
#  'benny_noun',
#  'bent_noun',
#  'bentwood_noun',
#  'benzene_noun',
#  'benzine_noun',
#  'beppo_noun',
#  'bequest_noun',
#  'ber_noun',
#  'berber_noun',
#  'bereavement_noun',
#  'beret_noun',
#  'berg_noun',
#  'bergman_noun',
#  'beriberi_noun',
#  'berliner_noun',
#  'berm_noun',
#  'bernadotte_noun',
#  'bernardo_noun',
#  'berry_noun',
#  'bers_noun',
#  'berserk_noun',
#  'berserker_noun',
#  'berth_noun',
#  'berthe_noun',
#  'bertie_noun',
#  'bertillon_noun',
#  'beryl_noun',
#  'beryllium_noun',
#  'besieger_noun',
#  'besoin_noun',
#  'besom_noun',
#  'bespoke_noun',
#  'bessemer_noun',
#  'bessie_noun',
#  'best-seller_noun',
#  'best-sellers_noun',
#  'bestiality_noun',
#  'bestknown_noun',
#  'bestowal_noun',
#  'bestowment_noun',
#  'bestseller_noun',
#  'bet_noun',
#  'beta_noun',
#  'betcha_noun',
#  'bete_noun',
#  'betel_noun',
#  'bethany_noun',
#  'bethel_noun',
#  'betide_noun',
#  'betrayal_noun',
#  'betrayer_noun',
#  'betroth_noun',
#  'betrothal_noun',
#  'betsey_noun',
#  'betsy_noun',
#  'bettah_noun',
#  "better'n_noun",
#  'better_noun',
#  'bettering_noun',
#  'betterment_noun',
#  'betther_noun',
#  'bettin_noun',
#  'betting_noun',
#  'bettor_noun',
#  'between_noun',
#  'beulah_noun',
#  'beurre_noun',
#  'bevan_noun',
#  'bevel_noun',
#  'beverage_noun',
#  'bevy_noun',
#  'bewilder_noun',
#  'bewilderment_noun',
#  'bey_noun',
#  'beyond_noun',
#  'bi_noun',
#  'bia_noun',
#  'bianca_noun',
#  'bias_noun',
#  'bib_noun',
#  'bible_noun',
#  'bibliographer_noun',
#  'bibliography_noun',
#  'bibliophile_noun',
#  'bicarbonate_noun',
#  'biceps_noun',
#  'bichloride_noun',
#  'bickering_noun',
#  'bicycle_noun',
#  'bicyclist_noun',
#  'bid_noun',
#  'bidder_noun',
#  'bidding_noun',
#  'biddy_noun',
#  'bien_noun',
#  'biennial_noun',
#  'bier_noun',
#  'bifocals_noun',
#  'big-game_noun',
#  'bigamist_noun',
#  'bigamy_noun',
#  'bigelow_noun',
#  "bigger'n_noun",
#  'bighorn_noun',
#  'bight_noun',
#  'biglow_noun',
#  'bigness_noun',
#  'bigot_noun',
#  'bigotry_noun',
#  'bigwig_noun',
#  'bijou_noun',
#  'bike_noun',
#  'bikini_noun',
#  'bile_noun',
#  'biler_noun',
#  'bilge_noun',
#  'bilin_noun',
#  'bility_noun',
#  'bill_noun',
#  'billboard_noun',
#  'billet-doux_noun',
#  'billet_noun',
#  'billeting_noun',
#  'billi_noun',
#  'billiard-room_noun',
#  'billiard_noun',
#  'billiards_noun',
#  'billie_noun',
#  'billing_noun',
#  'billionaire_noun',
#  'billionth_noun',
#  'billow_noun',
#  'billy_noun',
#  'biltmore_noun',
#  'bim_noun',
#  'bimeby_noun',
#  'bimetallism_noun',
#  'bin_noun',
#  'binary_noun',
#  'bind_noun',
#  'binder_noun',
#  'bindery_noun',
#  'binding_noun',
#  'binge_noun',
#  'bingo_noun',
#  'binnacle_noun',
#  'binoculars_noun',
#  'biochemist_noun',
#  'biochemistry_noun',
#  'biographer_noun',
#  'biography_noun',
#  'biologist_noun',
#  'biology_noun',
#  'bipartisanship_noun',
#  'biped_noun',
#  'biplane_noun',
#  'birch-bark_noun',
#  'birch-tree_noun',
#  'birch_noun',
#  'birchbark_noun',
#  'bird-cage_noun',
#  'bird-song_noun',
#  'bird_noun',
#  'birdcage_noun',
#  'birdie_noun',
#  'birdsong_noun',
#  'biretta_noun',
#  'birth-day_noun',
#  'birth-place_noun',
#  'birth-right_noun',
#  'birth_noun',
#  'birthday_noun',
#  'birthmark_noun',
#  'birthplace_noun',
#  'birthrate_noun',
#  'birthright_noun',
#  'biscuit_noun',
#  'bishop_noun',
#  'bishopric_noun',
#  'bismuth_noun',
#  'bison_noun',
#  'bisque_noun',
#  'bist_noun',
#  'bistro_noun',
#  'bit_noun',
#  'bitch_noun',
#  'bite_noun',
#  'biter_noun',
#  'bitin_noun',
#  'bitt_noun',
#  'bitter_noun',
#  'bitterer_noun',
#  'bittern_noun',
#  'bitterness_noun',
#  'bitumen_noun',
#  'bivalve_noun',
#  'bivouac_noun',
#  'biz_noun',
#  'bizness_noun',
#  'blab_noun',
#  'black-andwhite_noun',
#  'black_noun',
#  'blackamoor_noun',
#  'blackberry_noun',
#  'blackbird_noun',
#  'blackboard_noun',
#  'blackface_noun',
#  'blackfoot_noun',
#  'blackguard_noun',
#  'blackhead_noun',
#  'blackie_noun',
#  'blackjack_noun',
#  'blackleg_noun',
#  'blacklist_noun',
#  'blackmail_noun',
#  'blackmailer_noun',
#  'blackness_noun',
#  'blackout_noun',
#  'blacksmith_noun',
#  'blacksnake_noun',
#  'blackstone_noun',
#  'blacktop_noun',
#  'bladder_noun',
#  'blade_noun',
#  'blaine_noun',
#  'blame_noun',
#  'blanc_noun',
#  'blanch_noun',
#  'blanche_noun',
#  'blandishment_noun',
#  'blandness_noun',
#  'blank-book_noun',
#  'blank_noun',
#  'blanket_noun',
#  'blankness_noun',
#  'blare_noun',
#  'blaring_noun',
#  'blarney_noun',
#  'blas_noun',
#  'blaspheme_noun',
#  'blasphemer_noun',
#  'blasphemy_noun',
#  'blast_noun',
#  'blaster_noun',
#  'blasting_noun',
#  'blather_noun',
#  'blatherskite_noun',
#  'blaze_noun',
#  'blazer_noun',
#  'blazin_noun',
#  'blazon_noun',
#  'blazonry_noun',
#  'ble_noun',
#  'bleach_noun',
#  'bleacher_noun',
#  'bleaching_noun',
#  'bleakness_noun',
#  'bleat_noun',
#  'bleating_noun',
#  'bleecker_noun',
#  'bleeder_noun',
#  'bleedin_noun',
#  'blemish_noun',
#  'blend_noun',
#  'blender_noun',
#  'blending_noun',
#  'blessedness_noun',
#  'blessin_noun',
#  'blessing_noun',
#  'bleu_noun',
#  'blight_noun',
#  'blighter_noun',
#  'blighting_noun',
#  'blimp_noun',
#  'blind_noun',
#  'blinder_noun',
#  'blindfold_noun',
#  'blindman_noun',
#  'blindness_noun',
#  'blink_noun',
#  'blinker_noun',
#  'blinkin_noun',
#  'blinking_noun',
#  'bliss_noun',
#  'blister_noun',
#  'blitheness_noun',
#  'blitz_noun',
#  'blitzkrieg_noun',
#  'blizzard_noun',
#  'bloat_noun',
#  'blob_noun',
#  'bloc_noun',
#  'bloch_noun',
#  'block-house_noun',
#  'block_noun',
#  'blockade-runner_noun',
#  'blockade_noun',
#  'blockaders_noun',
#  'blockage_noun',
#  'blockbuster_noun',
#  'blocker_noun',
#  'blockhead_noun',
#  'blockhouse_noun',
#  'blocking_noun',
#  'bloke_noun',
#  'blond_noun',
#  'blonde_noun',
#  'blondness_noun',
#  'blood-drops_noun',
#  'blood-hound_noun',
#  'blood-hounds_noun',
#  'blood-letting_noun',
#  'blood-poisoning_noun',
#  'blood-pressure_noun',
#  'blood-stain_noun',
#  'blood-stains_noun',
#  'blood-vessel_noun',
#  'blood-vessels_noun',
#  'blood_noun',
#  'bloodhound_noun',
#  'bloodline_noun',
#  'bloodshed_noun',
#  'bloodstain_noun',
#  'bloodstream_noun',
#  'bloodsucker_noun',
#  'bloodthirstiness_noun',
#  'bloodthirsty_noun',
#  'bloom_noun',
#  'bloomer_noun',
#  'bloomin_noun',
#  'blossom_noun',
#  'blossoming_noun',
#  'blot_noun',
#  'blotch_noun',
#  'blotter_noun',
#  'blotto_noun',
#  'blount_noun',
#  'blouse_noun',
#  'blow-out_noun',
#  'blow-up_noun',
#  'blow_noun',
#  'blower_noun',
#  'blowin_noun',
#  'blowing_noun',
#  'blowout_noun',
#  'blowpipe_noun',
#  'blowtorch_noun',
#  'blowup_noun',
#  'blubber_noun',
#  'blucher_noun',
#  'bludgeon_noun',
#  'blue-bird_noun',
#  'blue-coats_noun',
#  'blue-stocking_noun',
#  'blue_noun',
#  'bluebeard_noun',
#  'bluebell_noun',
#  'blueberry_noun',
#  'bluebird_noun',
#  'bluebottle_noun',
#  'bluecoat_noun',
#  'bluefish_noun',
#  'bluegrass_noun',
#  'bluejacket_noun',
#  'bluejay_noun',
#  'blueness_noun',
#  'blueprint_noun',
#  'bluestocking_noun',
#  'bluff_noun',
#  'blum_noun',
#  'blunder_noun',
#  'blunderbuss_noun',
#  'blunderer_noun',
#  'blundering_noun',
#  'bluntness_noun',
#  'blur_noun',
#  'blurb_noun',
#  'blurring_noun',
#  'blush_noun',
#  'blushing_noun',
#  'bluster_noun',
#  'blustering_noun',
#  'bo_noun',
#  'boa-constrictor_noun',
#  'boa_noun',
#  'boar_noun',
#  'board_noun',
#  ...]

# %%
newunigram.to_csv("unigrams.csv")
