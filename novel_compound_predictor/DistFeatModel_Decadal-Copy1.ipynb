# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.mode.chained_assignment = None
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split,LeaveOneOut,KFold,RepeatedStratifiedKFold
from sklearn.decomposition import PCA,TruncatedSVD,NMF
# %matplotlib inline
import matplotlib
#matplotlib.use('agg')
matplotlib.style.use('ggplot')
import pickle as pkl
from matplotlib import pyplot as plt
from collections import Counter
from functools import reduce
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
compounds=pd.read_csv("/data/dharp/compounding/datasets/compounds_reduced.csv",sep="\t",index_col=0)
compounds=compounds.query('decade != 2000')
compounds=compounds.reindex()
compounds
# Out:
# /data/dharp/packages/miniconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                  modifier            head  decade          context  count  \
# 0                     a_n         aaaaa_n    1960              a_n      9
# 1                     a_n         aaaaa_n    1970              a_n     10
# 2                     a_n         aaaaa_n    1980              a_n      9
# 3                     a_n         aaaaa_n    1990              a_n     14
# 5                     a_n       addison_n    1960     publishing_n     14
# 6                     a_n       addison_n    1970     publishing_n     48
# 7                     a_n       addison_n    1980     publishing_n    103
# 8                     a_n       addison_n    1990     publishing_n     98
# 10                    a_n       addison_n    1960         wesley_n     14
# 11                    a_n       addison_n    1970         wesley_n     48
# 12                    a_n       addison_n    1980         wesley_n    103
# 13                    a_n       addison_n    1990         wesley_n     98
# 15                    a_n          anti_n    1960              b_n     27
# 16                    a_n          anti_n    1970              b_n     30
# 17                    a_n          anti_n    1980              b_n     41
# 18                    a_n          anti_n    1990              b_n     67
# 20                    a_n       archive_n    1960             am_n     27
# 21                    a_n       archive_n    1970             am_n     78
# 22                    a_n       archive_n    1980             am_n     28
# 23                    a_n       archive_n    1990             am_n     18
# 25                    a_n       archive_n    1960        general_n     34
# 26                    a_n       archive_n    1970        general_n     60
# 27                    a_n       archive_n    1980        general_n     10
# 28                    a_n       archive_n    1990        general_n     12
# 30                    a_n       archive_n    1960      neurology_n     20
# 31                    a_n       archive_n    1970      neurology_n     90
# 32                    a_n       archive_n    1980      neurology_n     48
# 33                    a_n       archive_n    1990      neurology_n     24
# 35                    a_n       archive_n    1960     psychiatry_n     17
# 36                    a_n       archive_n    1970     psychiatry_n     30
# ...                   ...             ...     ...              ...    ...
# 41516772     zwitterion_n  intermediate_n    1990  rearrangement_n     59
# 41516773     zwitterion_n  intermediate_n    1990           term_n     59
# 41516774     zwitterion_n     mechanism_n    1990           type_n    118
# 41516775     zwitterion_n         route_n    1990     attractive_a     57
# 41516776     zwitterion_n         route_n    1990           make_v    114
# 41516777     zwitterion_n         route_n    1990   substituents_n     57
# 41516778  zygapophyseal_n         joint_n    1980       cervical_a      3
# 41516779  zygapophyseal_n         joint_n    1990       cervical_a     84
# 41516781  zygapophyseal_n         joint_n    1980         change_n      8
# 41516782  zygapophyseal_n         joint_n    1990         change_n     36
# 41516784  zygapophyseal_n         joint_n    1980         lumbar_a     27
# 41516785  zygapophyseal_n         joint_n    1990         lumbar_a    139
# 41516787  zygapophyseal_n         joint_n    1990         source_n     22
# 41516790         zygote_n       nucleus_n    1970             be_v     11
# 41516791         zygote_n        result_n    1960       division_n      6
# 41516792         zygote_n        result_n    1970       division_n      8
# 41516793         zygote_n        result_n    1980       division_n      7
# 41516794         zygote_n        result_n    1990       division_n      9
# 41516796         zygote_n        result_n    1960      formation_n     11
# 41516797         zygote_n        result_n    1970      formation_n      6
# 41516798         zygote_n        result_n    1980      formation_n      6
# 41516799         zygote_n        result_n    1990      formation_n      6
# 41516801       zygotene_n         stage_n    1960        meiosis_n     18
# 41516802       zygotene_n         stage_n    1970        meiosis_n     22
# 41516803       zygotene_n         stage_n    1980        meiosis_n     31
# 41516804       zygotene_n         stage_n    1990        meiosis_n     19
# 41516806   zylobalsamum_n       process_n    1890             be_v     18
# 41516807   zylobalsamum_n       process_n    1920             be_v      5
# 41516809   zylobalsamum_n       process_n    1890           call_v     18
# 41516810   zylobalsamum_n       process_n    1920           call_v      5
#
#                             compounds
# 0                         a_n aaaaa_n
# 1                         a_n aaaaa_n
# 2                         a_n aaaaa_n
# 3                         a_n aaaaa_n
# 5                       a_n addison_n
# 6                       a_n addison_n
# 7                       a_n addison_n
# 8                       a_n addison_n
# 10                      a_n addison_n
# 11                      a_n addison_n
# 12                      a_n addison_n
# 13                      a_n addison_n
# 15                         a_n anti_n
# 16                         a_n anti_n
# 17                         a_n anti_n
# 18                         a_n anti_n
# 20                      a_n archive_n
# 21                      a_n archive_n
# 22                      a_n archive_n
# 23                      a_n archive_n
# 25                      a_n archive_n
# 26                      a_n archive_n
# 27                      a_n archive_n
# 28                      a_n archive_n
# 30                      a_n archive_n
# 31                      a_n archive_n
# 32                      a_n archive_n
# 33                      a_n archive_n
# 35                      a_n archive_n
# 36                      a_n archive_n
# ...                               ...
# 41516772  zwitterion_n intermediate_n
# 41516773  zwitterion_n intermediate_n
# 41516774     zwitterion_n mechanism_n
# 41516775         zwitterion_n route_n
# 41516776         zwitterion_n route_n
# 41516777         zwitterion_n route_n
# 41516778      zygapophyseal_n joint_n
# 41516779      zygapophyseal_n joint_n
# 41516781      zygapophyseal_n joint_n
# 41516782      zygapophyseal_n joint_n
# 41516784      zygapophyseal_n joint_n
# 41516785      zygapophyseal_n joint_n
# 41516787      zygapophyseal_n joint_n
# 41516790           zygote_n nucleus_n
# 41516791            zygote_n result_n
# 41516792            zygote_n result_n
# 41516793            zygote_n result_n
# 41516794            zygote_n result_n
# 41516796            zygote_n result_n
# 41516797            zygote_n result_n
# 41516798            zygote_n result_n
# 41516799            zygote_n result_n
# 41516801           zygotene_n stage_n
# 41516802           zygotene_n stage_n
# 41516803           zygotene_n stage_n
# 41516804           zygotene_n stage_n
# 41516806     zylobalsamum_n process_n
# 41516807     zylobalsamum_n process_n
# 41516809     zylobalsamum_n process_n
# 41516810     zylobalsamum_n process_n
#
# [35677592 rows x 6 columns]

# %%
heads=pd.read_csv("/data/dharp/compounding/datasets/heads_reduced.csv",sep="\t")
heads=heads.query('decade != 2000')
heads=heads.reindex()
heads
# Out:
#                    head  decade        context  count
# 0                   a_n    1800            a_a      4
# 1                   a_n    1810            a_a     20
# 2                   a_n    1820            a_a     10
# 3                   a_n    1830            a_a     14
# 4                   a_n    1840            a_a     14
# 5                   a_n    1850            a_a     34
# 6                   a_n    1860            a_a     52
# 7                   a_n    1870            a_a     14
# 8                   a_n    1880            a_a     23
# 9                   a_n    1890            a_a     30
# 10                  a_n    1900            a_a     65
# 11                  a_n    1910            a_a    225
# 12                  a_n    1920            a_a    201
# 13                  a_n    1930            a_a    263
# 14                  a_n    1940            a_a    563
# 15                  a_n    1950            a_a    929
# 16                  a_n    1960            a_a   1043
# 17                  a_n    1970            a_a   1039
# 18                  a_n    1980            a_a   1184
# 19                  a_n    1990            a_a   1679
# 21                  a_n    1800            a_n     16
# 22                  a_n    1810            a_n     49
# 23                  a_n    1820            a_n     36
# 24                  a_n    1830            a_n     37
# 25                  a_n    1840            a_n     25
# 26                  a_n    1850            a_n     56
# 27                  a_n    1860            a_n     42
# 28                  a_n    1870            a_n     60
# 29                  a_n    1880            a_n    110
# 30                  a_n    1890            a_n    180
# ...                 ...     ...            ...    ...
# 31425719      zwingli_n    1990  switzerland_n      1
# 31425721      zwingli_n    1970     theology_n      1
# 31425722      zwingli_n    1980     theology_n     41
# 31425723      zwingli_n    1990     theology_n    124
# 31425725      zwingli_n    1900         work_n     12
# 31425726      zwingli_n    1910         work_n     20
# 31425727      zwingli_n    1920         work_n     12
# 31425728      zwingli_n    1930         work_n      2
# 31425729      zwingli_n    1940         work_n      4
# 31425730      zwingli_n    1950         work_n     19
# 31425731      zwingli_n    1960         work_n     35
# 31425732      zwingli_n    1970         work_n     17
# 31425733      zwingli_n    1980         work_n     52
# 31425734      zwingli_n    1990         work_n     49
# 31425736      zwingli_n    1900       zurich_n      6
# 31425737      zwingli_n    1910       zurich_n      1
# 31425738      zwingli_n    1950       zurich_n      1
# 31425739      zwingli_n    1960       zurich_n      5
# 31425740      zwingli_n    1970       zurich_n      8
# 31425741      zwingli_n    1980       zurich_n     21
# 31425742      zwingli_n    1990       zurich_n     44
# 31425744      zygmunt_n    1990       bauman_n     27
# 31425746      zygmunt_n    1990         have_v     15
# 31425748  zygomycetes_n    1970       member_n      4
# 31425749  zygomycetes_n    1980       member_n     10
# 31425750  zygomycetes_n    1990       member_n     18
# 31425752       zygote_n    1990     cultured_a     67
# 31425754       zygote_n    1990  development_n     42
# 31425756       zygote_n    1980       genome_n     25
# 31425757       zygote_n    1990       genome_n     15
#
# [27727848 rows x 4 columns]

# %%
modifiers=pd.read_csv("/data/dharp/compounding/datasets/modifiers_reduced.csv",sep="\t")
modifiers=modifiers.query('decade != 2000')
modifiers=modifiers.reindex()
modifiers
# Out:
#                 modifier  decade      context  count
# 0                    a_n    1830          a_n      1
# 1                    a_n    1870          a_n      1
# 2                    a_n    1880          a_n      3
# 3                    a_n    1890          a_n      1
# 4                    a_n    1900          a_n      1
# 5                    a_n    1910          a_n      2
# 6                    a_n    1920          a_n     15
# 7                    a_n    1930          a_n     34
# 8                    a_n    1940          a_n     13
# 9                    a_n    1950          a_n     39
# 10                   a_n    1960          a_n    102
# 11                   a_n    1970          a_n    121
# 12                   a_n    1980          a_n    139
# 13                   a_n    1990          a_n    130
# 15                   a_n    1990  accession_n     20
# 17                   a_n    1920    account_n      2
# 18                   a_n    1930    account_n      1
# 19                   a_n    1950    account_n      5
# 20                   a_n    1960    account_n      2
# 21                   a_n    1970    account_n      5
# 22                   a_n    1980    account_n      5
# 23                   a_n    1990    account_n     12
# 25                   a_n    1800        act_n      1
# 26                   a_n    1810        act_n      2
# 27                   a_n    1820        act_n      4
# 28                   a_n    1830        act_n      5
# 29                   a_n    1840        act_n      5
# 30                   a_n    1850        act_n      4
# 31                   a_n    1860        act_n      2
# 32                   a_n    1870        act_n      5
# ...                  ...     ...          ...    ...
# 26742018        zygote_n    1980         be_v      7
# 26742019        zygote_n    1990         be_v      1
# 26742021        zygote_n    1920   division_n      2
# 26742022        zygote_n    1930   division_n      3
# 26742023        zygote_n    1950   division_n      4
# 26742024        zygote_n    1960   division_n      6
# 26742025        zygote_n    1970   division_n      8
# 26742026        zygote_n    1980   division_n      7
# 26742027        zygote_n    1990   division_n      9
# 26742029      zygotene_n    1950    meiosis_n      4
# 26742030      zygotene_n    1960    meiosis_n     18
# 26742031      zygotene_n    1970    meiosis_n     22
# 26742032      zygotene_n    1980    meiosis_n     31
# 26742033      zygotene_n    1990    meiosis_n     19
# 26742035  zylobalsamum_n    1890         be_v     18
# 26742036  zylobalsamum_n    1900         be_v      2
# 26742037  zylobalsamum_n    1910         be_v      1
# 26742038  zylobalsamum_n    1920         be_v      5
# 26742039  zylobalsamum_n    1930         be_v      1
# 26742040  zylobalsamum_n    1960         be_v      2
# 26742041  zylobalsamum_n    1970         be_v      1
# 26742042  zylobalsamum_n    1990         be_v      3
# 26742044  zylobalsamum_n    1890       call_v     18
# 26742045  zylobalsamum_n    1900       call_v      2
# 26742046  zylobalsamum_n    1910       call_v      1
# 26742047  zylobalsamum_n    1920       call_v      5
# 26742048  zylobalsamum_n    1930       call_v      1
# 26742049  zylobalsamum_n    1960       call_v      2
# 26742050  zylobalsamum_n    1970       call_v      1
# 26742051  zylobalsamum_n    1990       call_v      3
#
# [23495976 rows x 4 columns]

# %%
compound_decade_counts=compounds.groupby(['decade'])['count'].sum().to_frame()
compound_decade_counts.columns=['N']
compound_decade_counts
# Out:
#                 N
# decade
# 1800      1299884
# 1810      2183326
# 1820      3456974
# 1830      4890701
# 1840      6562000
# 1850     10533767
# 1860      9437783
# 1870     12216442
# 1880     18060550
# 1890     23739386
# 1900     35322414
# 1910     37648397
# 1920     39606669
# 1930     42377993
# 1940     50683276
# 1950     82881773
# 1960    160087560
# 1970    237221993
# 1980    337843074
# 1990    551627887

# %% [markdown]
# ## PPMI , LMI, LL

# %%
XY=compounds.groupby(['modifier','head','decade'])['count'].sum().to_frame()
XY.columns=['a']
X_star=compounds.groupby(['modifier','decade'])['count'].sum().to_frame()
X_star.columns=['x_star']
Y_star=compounds.groupby(['head','decade'])['count'].sum().to_frame()
Y_star.columns=['star_y']
merge1=pd.merge(XY.reset_index(),X_star.reset_index(),on=['modifier','decade'])
information_feat=pd.merge(merge1,Y_star.reset_index(),on=['head','decade'])
information_feat['b']=information_feat['x_star']-information_feat['a']
information_feat['c']=information_feat['star_y']-information_feat['a']
information_feat=pd.merge(information_feat,compound_decade_counts.reset_index(),on=['decade'])
information_feat['d']=information_feat['N']-(information_feat['a']+information_feat['b']+information_feat['c'])
information_feat['x_bar_star']=information_feat['N']-information_feat['x_star']
information_feat['star_y_bar']=information_feat['N']-information_feat['star_y']
#information_feat['LR']=-2*np.sum(information_feat['a']*np.log2((information_feat['a']*information_feat['N'])/(information_feat['x_star']*information_feat['star_y'])))
information_feat.set_index(['modifier','head','decade'],inplace=True)
information_feat.replace(0,0.001,inplace=True)
information_feat['log_ratio']=2*(information_feat['a']*np.log((information_feat['a']*information_feat['N'])/(information_feat['x_star']*information_feat['star_y']))+\
information_feat['b']*np.log((information_feat['b']*information_feat['N'])/(information_feat['x_star']*information_feat['star_y_bar']))+\
information_feat['c']*np.log((information_feat['c']*information_feat['N'])/(information_feat['x_bar_star']*information_feat['star_y']))+\
information_feat['d']*np.log((information_feat['d']*information_feat['N'])/(information_feat['x_bar_star']*information_feat['star_y_bar'])))
information_feat['ppmi']=np.log2((information_feat['a']*information_feat['N'])/(information_feat['x_star']*information_feat['star_y']))
information_feat['local_mi']=information_feat['a']*information_feat['ppmi']
information_feat.ppmi.loc[information_feat.ppmi<=0]=0
information_feat.drop(['a','x_star','star_y','b','c','d','N','d','x_bar_star','star_y_bar'],axis=1,inplace=True)
information_feat
# Out:
#                                       log_ratio   ppmi  local_mi
# modifier        head          decade
# a_n             aaaaa_n       1960      165.271 13.248   119.228
#                 addison_n     1960      284.397  8.733   244.523
# adherents_n     addison_n     1960     1327.127 17.610   986.184
# college_n       addison_n     1960      107.410  4.324   112.417
# conceits_n      addison_n     1960      502.546 15.743   393.583
# invention_n     addison_n     1960      338.137 13.010   273.200
# mechanism_n     addison_n     1960      539.149 14.312   429.353
# mr_n            addison_n     1960       78.429  7.078    70.780
# premises_n      addison_n     1960      231.242 12.529   187.930
# qualification_n addison_n     1960      263.158 11.956   215.214
# secretary_n     addison_n     1960       61.417  5.837    58.367
# technology_n    addison_n     1960     2608.539 10.403  2122.150
# time_n          addison_n     1960       31.231  2.409    43.364
# tv_n            addison_n     1960       80.196  7.206    72.062
# university_n    addison_n     1960     1282.999  7.255  1117.314
# view_n          addison_n     1960      128.490  7.597   113.953
# a_n             anti_n        1960       95.704  3.901   105.327
# allied_n        anti_n        1960      117.585  2.620   157.171
# american_n      anti_n        1960    11751.163  4.307 11977.939
# and_n           anti_n        1960      147.433  6.738   134.751
# argentine_n     anti_n        1960      549.293  6.772   501.162
# b_n             anti_n        1960     1322.081  5.026  1316.766
# c_n             anti_n        1960       85.377  2.186   126.774
# cabinet_n       anti_n        1960        6.678  1.125    15.752
# church_n        anti_n        1960       79.801  1.806   133.676
# city_n          anti_n        1960     4362.586  4.574  4454.965
# community_n     anti_n        1960        7.592  0.000   -16.112
# county_n        anti_n        1960     1340.658  3.839  1478.020
# e_n             anti_n        1960       18.612  2.150    27.947
# federal_n       anti_n        1960     4917.202  4.018  5251.219
# ...                                         ...    ...       ...
# years_n         agathon_n     1930      883.639 10.117   637.352
#                 argentina_n   1930      224.383 10.117   161.867
#                 ethiopia_n    1930      140.231 10.117   101.167
#                 galvanism_n   1930      336.588 10.117   242.801
#                 headmaster_n  1930      238.408 10.117   171.984
#                 loser_n       1930      420.745 10.117   303.501
#                 profusion_n   1930      252.434 10.117   182.101
#                 tinoco_n      1930      126.206 10.117    91.050
# yeomen_n        warder_n      1930      294.532 22.167   199.502
# yesterday_n     whitesides_n  1930      229.208 13.776   165.318
# yom_n           kippur_n      1930    11001.213 16.552  7299.510
# yorker_n        cartoon_n     1930      578.576 19.555   410.664
# young_n         contributor_n 1930      449.830 10.816   324.471
#                 czech_n       1930      749.772 10.816   540.785
#                 irelander_n   1930      284.877 10.816   205.498
#                 mccarthy_n    1930      359.854 10.816   259.577
#                 norval_n      1930      404.842 10.816   292.024
#                 winnie_n      1930     3645.974 10.816  2628.216
# youth_n         aversion_n    1930      362.067 13.057   261.132
#                 daggoo_n      1930      778.665 13.057   561.435
#                 hopeful_n     1930      199.109 13.057   143.623
#                 hostel_n      1930     2138.636 13.057  1540.681
#                 partridge_n   1930      362.067 13.057   261.132
#                 presage_n     1930      470.724 13.057   339.472
# zealand_n       paddle_n      1930      262.583 12.627   189.403
#                 spinach_n     1930      245.074 12.627   176.776
# zeus_n          olympios_n    1930      833.800 18.061   596.003
#                 olympius_n    1930     1012.823 18.061   722.428
#                 polieus_n     1930      782.800 18.061   559.881
# zone_n          homologue_n   1930      641.600 16.485   461.582
#
# [3781847 rows x 3 columns]

# %% [markdown]
# # Cosine features

# %%
modifier_decade_counts=modifiers.groupby(['decade'])['count'].sum().to_frame()
modifier_decade_counts.columns=['N']
modifier_decade_counts
# Out:
#                 N
# decade
# 1800      1875025
# 1810      3132730
# 1820      4925152
# 1830      7229042
# 1840      9705181
# 1850     15688004
# 1860     14102063
# 1870     17537155
# 1880     26200200
# 1890     34391496
# 1900     51451738
# 1910     55272599
# 1920     57602599
# 1930     60166714
# 1940     70501540
# 1950    110597851
# 1960    210913465
# 1970    300061024
# 1980    411252046
# 1990    653712546

# %%
head_decade_counts=heads.groupby(['decade'])['count'].sum().to_frame()
head_decade_counts.columns=['N']
head_decade_counts
# Out:
#                 N
# decade
# 1800      2169414
# 1810      3624671
# 1820      5705766
# 1830      8349311
# 1840     11093500
# 1850     18032240
# 1860     16195725
# 1870     20093252
# 1880     30018992
# 1890     39295684
# 1900     58568163
# 1910     62093990
# 1920     64626166
# 1930     67432086
# 1940     78522855
# 1950    123112226
# 1960    235158518
# 1970    333924530
# 1980    457089107
# 1990    727640532

# %%
modifier_denom=modifiers.groupby(['modifier','decade'])['count'].agg(lambda x: np.sqrt(np.sum(np.square(x)))).to_frame()
modifier_denom.columns=['modifier_denom']
modifier_denom
# Out:
#                         modifier_denom
# modifier        decade
# a_n             1800            49.639
#                 1810            57.210
#                 1820            58.932
#                 1830           101.701
#                 1840           189.079
#                 1850           345.339
#                 1860           401.531
#                 1870           568.809
#                 1880          1011.293
#                 1890          1644.760
#                 1900          1978.221
#                 1910          1869.718
#                 1920          1778.635
#                 1930          1699.540
#                 1940          1009.567
#                 1950          1241.364
#                 1960          1392.112
#                 1970          2197.178
#                 1980          2244.908
#                 1990          2946.935
# aa_n            1800             7.211
#                 1810            34.771
#                 1820            24.920
#                 1830            10.677
#                 1850             2.828
#                 1860             5.099
#                 1870            15.652
#                 1880             6.403
#                 1900            15.620
#                 1910            41.725
# ...                                ...
# zwitterion_n    1950             7.000
#                 1960             6.000
#                 1970            14.000
#                 1980             5.657
#                 1990           233.067
# zygapophyseal_n 1960             3.000
#                 1970             2.828
#                 1980            28.320
#                 1990           166.352
# zygote_n        1920             3.606
#                 1930             6.708
#                 1940             2.000
#                 1950             8.944
#                 1960             7.211
#                 1970            13.601
#                 1980             9.899
#                 1990             9.055
# zygotene_n      1950             4.000
#                 1960            18.000
#                 1970            22.000
#                 1980            31.000
#                 1990            19.000
# zylobalsamum_n  1890            25.456
#                 1900             2.828
#                 1910             1.414
#                 1920             7.071
#                 1930             1.414
#                 1960             2.828
#                 1970             1.414
#                 1990             4.243
#
# [514067 rows x 1 columns]

# %%
head_denom=heads.groupby(['head',"decade"])['count'].agg(lambda x: np.sqrt(np.sum(np.square(x)))).to_frame()
head_denom.columns=['head_denom']
head_denom
# Out:
#                       head_denom
# head          decade
# a_n           1800       269.318
#               1810       516.640
#               1820       653.046
#               1830       566.634
#               1840       634.276
#               1850       777.192
#               1860       694.444
#               1870      1042.308
#               1880      1403.479
#               1890      1929.539
#               1900      2829.036
#               1910      4079.444
#               1920      6502.183
#               1930      7771.830
#               1940      9663.573
#               1950     16709.251
#               1960     27050.112
#               1970     39028.216
#               1980     52834.975
#               1990     69097.441
# aa_n          1800         9.798
#               1810        18.655
#               1820        24.454
#               1830        10.247
#               1840        11.790
#               1850        47.958
#               1860        17.607
#               1870        19.468
#               1880        23.195
#               1890        27.092
# ...                          ...
# zvezda_n      1970        78.657
#               1980        74.679
#               1990       145.801
# zvi_n         1940         2.828
#               1950        25.768
#               1960        47.791
#               1970        58.327
#               1980        74.047
#               1990        92.785
# zwingli_n     1850         2.828
#               1860         3.162
#               1870         3.317
#               1880        12.845
#               1890        11.874
#               1900        25.729
#               1910        37.855
#               1920        31.097
#               1930         8.775
#               1940        18.868
#               1950        43.898
#               1960        64.761
#               1970        57.061
#               1980       137.139
#               1990       288.285
# zygmunt_n     1990        30.887
# zygomycetes_n 1970         4.000
#               1980        10.000
#               1990        18.000
# zygote_n      1980        25.000
#               1990        80.486
#
# [586758 rows x 1 columns]

# %%
compound_denom=compounds.groupby(['modifier','head',"decade"])['count'].agg(lambda x: np.sqrt(np.sum(np.square(x)))).to_frame()
compound_denom.columns=['compound_denom']
compound_denom
# Out:
#                                        compound_denom
# modifier        head           decade
# a_n             aaaaa_n        1960             9.000
#                                1970            10.000
#                                1980             9.000
#                                1990            14.000
#                 addison_n      1960            19.799
#                                1970            67.882
#                                1980           145.664
#                                1990           138.593
#                 anti_n         1960            27.000
#                                1970            30.000
#                                1980            41.000
#                                1990            67.000
#                 archive_n      1960            50.735
#                                1970           136.689
#                                1980            56.683
#                                1990            32.863
#                 atom_n         1940             9.000
#                                1950            23.770
#                                1960            25.495
#                                1970            13.038
#                                1980             9.899
#                                1990             7.071
#                 b_n            1800            16.062
#                                1810            43.704
#                                1820            57.793
#                                1830            99.905
#                                1840           181.163
#                                1850           341.621
#                                1860           395.487
#                                1870           564.459
# ...                                               ...
# zurich_n        government_n   1900            14.177
#                                1910            14.967
#                                1950             7.483
#                                1960            11.225
#                 seminar_n      1970           144.530
#                                1980           258.544
#                                1990           362.258
# zwemmer_n       gallery_n      1960            18.974
#                                1970            17.292
#                                1980            21.213
#                                1990            31.654
# zwinglische_n   reformation_n  1980            32.000
#                                1990            55.000
# zwitterion_n    form_n         1970            14.000
#                 intermediate_n 1990           144.520
#                 mechanism_n    1990           118.000
#                 route_n        1990           139.621
# zygapophyseal_n joint_n        1980            28.320
#                                1990           167.800
# zygote_n        nucleus_n      1970            11.000
#                 result_n       1960            12.530
#                                1970            10.000
#                                1980             9.220
#                                1990            10.817
# zygotene_n      stage_n        1960            18.000
#                                1970            22.000
#                                1980            31.000
#                                1990            19.000
# zylobalsamum_n  process_n      1890            25.456
#                                1920             7.071
#
# [3781847 rows x 1 columns]

# %% [markdown]
# ### Similarity between Modifier and Compound

# %%
mod_cols=modifiers.columns.tolist()
mod_cols[-1]="mod_count"
modifiers.columns=mod_cols
#compounds.drop(['comp_count'],axis=1,inplace=True)
comp_cols=compounds.columns.tolist()
comp_cols[-1]="comp_count"
compounds.columns=comp_cols
compound_modifier_sim=pd.merge(compounds,modifiers,on=["modifier","context",'decade'])
compound_modifier_sim['numerator']=compound_modifier_sim['comp_count']*compound_modifier_sim['mod_count']
compound_modifier_sim=compound_modifier_sim.groupby(['modifier','head','decade'])['numerator'].sum().to_frame()
compound_modifier_sim=pd.merge(compound_modifier_sim.reset_index(),compound_denom.reset_index(),on=["modifier","head",'decade'])
compound_modifier_sim=pd.merge(compound_modifier_sim,modifier_denom.reset_index(),on=['modifier','decade'])
compound_modifier_sim['sim_with_modifier']=compound_modifier_sim['numerator']/(compound_modifier_sim['compound_denom']*compound_modifier_sim['modifier_denom'])
compound_modifier_sim.set_index(['modifier','head','decade'],inplace=True)
compound_modifier_sim.drop(['numerator','compound_denom'],axis=1,inplace=True)
compound_modifier_sim

# %%
compound_modifier_sim.sim_with_modifier.describe()

# %%
_=compound_modifier_sim.hist(by= 'decade',column ='sim_with_modifier', figsize=(20, 20),bins=100,density=True,sharex=True,sharey=True,range=(-0.1,1.1))

# %% [markdown]
# ### Similarity between Head and Compound

# %%
ppmi_compound_head_sim=pd.merge(new_compounds.reset_index(),new_heads.reset_index(),on=["head","context","decade"])

ppmi_compound_head_sim['numerator']=ppmi_compound_head_sim['compound_ppmi']*ppmi_compound_head_sim['head_ppmi']
ppmi_compound_head_sim=ppmi_compound_head_sim.groupby(['modifier','head','decade'])['numerator'].sum().to_frame()
ppmi_compound_head_sim=pd.merge(ppmi_compound_head_sim.reset_index(),ppmi_compound_denom.reset_index(),on=["modifier","head","decade"])
ppmi_compound_head_sim=pd.merge(ppmi_compound_head_sim,ppmi_head_denom.reset_index(),on=['head','decade'])
ppmi_compound_head_sim['sim_with_head']=ppmi_compound_head_sim['numerator']/(ppmi_compound_head_sim['compound_denom']*ppmi_compound_head_sim['head_denom'])
ppmi_compound_head_sim.set_index(['modifier','head','decade'],inplace=True)
ppmi_compound_head_sim.drop(['numerator','compound_denom'],axis=1,inplace=True)
ppmi_compound_head_sim


head_cols=heads.columns.tolist()
head_cols[-1]="head_count"
heads.columns=head_cols

compound_head_sim=pd.merge(compounds,heads,on=["head","context",'decade'])
compound_head_sim['numerator']=compound_head_sim['comp_count']*compound_head_sim['head_count']
compound_head_sim=compound_head_sim.groupby(['modifier','head','decade'])['numerator'].sum().to_frame()
compound_head_sim=pd.merge(compound_head_sim.reset_index(),compound_head_sim.reset_index(),on=["modifier","head",'decade'])
compound_head_sim=pd.merge(compound_head_sim,modifier_denom.reset_index(),on=['modifier','decade'])
compound_head_sim['sim_with_modifier']=compound_head_sim['numerator']/(compound_head_sim['compound_denom']*compound_head_sim['modifier_denom'])
compound_head_sim.set_index(['modifier','head','decade'],inplace=True)
compound_head_sim.drop(['numerator','compound_denom'],axis=1,inplace=True)
compound_head_sim
# Out:
#                                       head_denom  sim_with_head
# modifier        head          decade
# a_n             aaaaa_n       1960        15.970          1.000
#                               1970        16.136          1.000
#                               1980        16.288          1.000
#                               1990        16.553          1.000
#                 addison_n     1960        92.298          0.232
# adherents_n     addison_n     1960        92.298          0.200
# college_n       addison_n     1960        92.298          0.232
# conceits_n      addison_n     1960        92.298          0.185
# invention_n     addison_n     1960        92.298          0.165
# mechanism_n     addison_n     1960        92.298          0.165
# mr_n            addison_n     1960        92.298          0.079
# premises_n      addison_n     1960        92.298          0.150
# qualification_n addison_n     1960        92.298          0.110
# secretary_n     addison_n     1960        92.298          0.104
# technology_n    addison_n     1960        92.298          0.271
# time_n          addison_n     1960        92.298          0.164
# tv_n            addison_n     1960        92.298          0.232
# university_n    addison_n     1960        92.298          0.236
# view_n          addison_n     1960        92.298          0.089
# a_n             addison_n     1970        85.108          0.261
# adherents_n     addison_n     1970        85.108          0.204
# college_n       addison_n     1970        85.108          0.261
# conceits_n      addison_n     1970        85.108          0.202
# technology_n    addison_n     1970        85.108          0.290
# tv_n            addison_n     1970        85.108          0.261
# university_n    addison_n     1970        85.108          0.267
# a_n             addison_n     1980        83.640          0.269
# conceits_n      addison_n     1980        83.640          0.170
# group_n         addison_n     1980        83.640          0.281
# invention_n     addison_n     1980        83.640          0.166
# ...                                          ...            ...
# zocor_n         zocor_n       1990        25.334          1.000
# zone_n          aride_n       1960        26.143          1.000
#                               1970        26.433          1.000
#                               1980        26.933          1.000
#                 contigue_n    1940        16.094          1.000
#                               1960        15.932          1.000
#                               1970        16.134          1.000
#                               1980        16.359          1.000
#                               1990        16.739          1.000
#                 flung_n       1830        22.689          1.000
#                               1840        23.035          1.000
#                               1860        23.240          1.000
#                               1870        27.257          0.859
#                               1900        23.806          1.000
#                 homologue_n   1930        15.746          1.000
#                               1940        16.094          1.000
#                               1950        16.457          0.970
#                               1960        15.932          1.000
#                               1980        24.516          0.654
#                 ophiolites_n  1990        23.756          1.000
#                 residuum_n    1960        39.938          0.583
#                               1980        32.574          0.736
#                               1990        41.055          0.587
# zones_n         arides_n      1970        22.978          1.000
#                 synaptiques_n 1960        25.856          1.000
#                               1970        26.283          1.000
#                               1980        26.723          1.000
# zoo_n           pottet_n      1900        20.361          1.000
# zoology_n       riley_n       1940        67.239          0.196
# zooplankton_n   biomass_n     1950        34.525          0.646
#
# [3781847 rows x 2 columns]

# %%
_=ppmi_compound_head_sim.hist(by= 'decade',column ='sim_with_head', figsize=(20, 20),bins=100,sharex=True,sharey=True,normed=True,range=(-0.1,1.1))

# %%
ppmi_constituent_sim=pd.merge(new_heads.reset_index(),new_compounds.reset_index(),on=["head","context","decade"])
ppmi_constituent_sim=pd.merge(ppmi_constituent_sim,new_modifiers.reset_index(),on=["modifier","context","decade"])
ppmi_constituent_sim['numerator']=ppmi_constituent_sim['head_ppmi']*ppmi_constituent_sim['modifier_ppmi']
ppmi_constituent_sim=ppmi_constituent_sim.groupby(['modifier','head','decade'])['numerator'].sum().to_frame()
ppmi_constituent_sim=pd.merge(ppmi_constituent_sim.reset_index(),ppmi_head_denom.reset_index(),on=["head","decade"])
ppmi_constituent_sim=pd.merge(ppmi_constituent_sim,ppmi_modifier_denom.reset_index(),on=["modifier","decade"])
ppmi_constituent_sim['sim_bw_constituents']=ppmi_constituent_sim['numerator']/(ppmi_constituent_sim['head_denom']*ppmi_constituent_sim['modifier_denom'])
ppmi_constituent_sim.set_index(['modifier','head','decade'],inplace=True)
ppmi_constituent_sim.drop(['numerator','modifier_denom','head_denom'],axis=1,inplace=True)
ppmi_constituent_sim
# Out:
#                                      sim_bw_constituents
# modifier      head           decade
# a_n           aaaaa_n        1960                  0.059
#               addison_n      1960                  0.012
#               anti_n         1960                  0.005
#               archive_n      1960                  0.014
#               atom_n         1960                  0.003
#               b_n            1960                  0.044
#               band_n         1960                  0.005
#               bell_n         1960                  0.007
#               bibliography_n 1960                  0.058
#               bill_n         1960                  0.001
#               briefe_n       1960                  0.036
#               bunch_n        1960                  0.028
#               c_n            1960                  0.013
#               calendar_n     1960                  0.004
#               campaign_n     1960                  0.001
#               cell_n         1960                  0.004
#               century_n      1960                  0.019
#               chronicle_n    1960                  0.004
#               co_n           1960                  0.002
#               code_n         1960                  0.003
#               coffin_n       1960                  0.017
#               collection_n   1960                  0.005
#               commentary_n   1960                  0.004
#               connecticut_n  1960                  0.012
#               corporation_n  1960                  0.002
#               council_n      1960                  0.003
#               cross_n        1960                  0.003
#               daily_n        1960                  0.026
#               decade_n       1960                  0.007
#               description_n  1960                  0.005
# ...                                                  ...
# yom_n         kippur_n       1890                  0.999
#                              1900                  1.000
#                              1910                  0.978
#                              1920                  0.986
#                              1930                  0.992
#                              1940                  0.983
#                              1950                  0.979
#                              1960                  0.967
#                              1970                  0.972
#                              1980                  0.976
#                              1990                  0.974
# yonder_n      copse_n        1860                  0.465
# younger_n     pliny_n        1820                  0.681
# yucca_n       pollination_n  1890                  0.771
#                              1910                  0.542
# zeiss_n       binoculars_n   1940                  0.437
#                              1970                  0.235
#               counting_n     1910                  0.428
# zeus_n        olympius_n     1840                  0.501
#                              1850                  0.299
#                              1860                  0.304
# zhuhai_n      sezs_n         1980                  0.701
#                              1990                  0.678
# zinovievite_n terrorist_n    1940                  0.689
#                              1950                  0.559
# zone_n        flung_n        1830                  1.000
#                              1860                  0.802
#                              1870                  0.700
# zoo_n         pottet_n       1900                  1.000
# zoot_n        sims_n         1960                  0.509
#
# [3734422 rows x 1 columns]

# %%
_=ppmi_constituent_sim.hist(by= 'decade',column ='sim_bw_constituents', figsize=(20, 20),bins=100,sharex=True,sharey=True,normed=True,range=(-0.1,1.1))

# %%
dfs = [ppmi_constituent_sim.reset_index(), ppmi_compound_head_sim.reset_index(), ppmi_compound_modifier_sim.reset_index(), information_feat.reset_index()]
compounds_final = reduce(lambda left,right: pd.merge(left,right,on=['modifier','head','decade']), dfs)
compounds_final.drop(['head_denom','modifier_denom'],axis=1,inplace=True)
compounds_final=pd.pivot_table(compounds_final, index=['modifier','head'], columns=['decade'])
compounds_final.fillna(0,inplace=True)
compounds_final -= compounds_final.min()
compounds_final /= compounds_final.max()
compounds_final_1=compounds_final.columns.get_level_values(0)
compounds_final_2=compounds_final.columns.get_level_values(1)

cur_year=0
new_columns=[]
for year in compounds_final_2:
    new_columns.append(str(year)+"_"+compounds_final_1[cur_year])
    cur_year+=1
compounds_final.columns=new_columns
compounds_final
# Out:
#                                 1800_local_mi  1810_local_mi  1820_local_mi  \
# modifier        head
# a_n             aaaaa_n                 0.006          0.005          0.004
#                 addison_n               0.006          0.005          0.004
#                 anti_n                  0.006          0.005          0.004
#                 archive_n               0.006          0.005          0.004
#                 atom_n                  0.006          0.005          0.004
#                 b_n                     0.007          0.008          0.006
#                 band_n                  0.006          0.005          0.004
#                 baseball_n              0.006          0.005          0.004
#                 behavior_n              0.006          0.005          0.004
#                 bell_n                  0.006          0.005          0.004
#                 berkley_n               0.006          0.005          0.004
#                 bibliography_n          0.006          0.005          0.004
#                 bill_n                  0.006          0.005          0.004
#                 bird_n                  0.006          0.005          0.004
#                 board_n                 0.006          0.005          0.004
#                 book_n                  0.006          0.005          0.004
#                 boswell_n               0.006          0.005          0.004
#                 brand_n                 0.006          0.005          0.004
#                 briefe_n                0.006          0.005          0.004
#                 bunch_n                 0.006          0.005          0.004
#                 burn_n                  0.006          0.005          0.004
#                 c_n                     0.010          0.006          0.004
#                 calendar_n              0.006          0.005          0.004
#                 call_n                  0.006          0.005          0.004
#                 campaign_n              0.006          0.005          0.004
#                 cassell_n               0.006          0.005          0.004
#                 cat_n                   0.006          0.005          0.004
#                 cataloguing_n           0.006          0.005          0.004
#                 cell_n                  0.006          0.005          0.004
#                 century_n               0.006          0.005          0.004
# ...                                       ...            ...            ...
# zuni_n          mountain_n              0.006          0.005          0.004
#                 origin_n                0.006          0.005          0.004
#                 prehistory_n            0.006          0.005          0.004
#                 religion_n              0.006          0.005          0.004
#                 ruin_n                  0.006          0.005          0.004
#                 sacred_n                0.006          0.005          0.004
#                 social_n                0.006          0.005          0.004
#                 tradition_n             0.006          0.005          0.004
#                 tribe_n                 0.006          0.005          0.004
#                 village_n               0.006          0.005          0.004
#                 war_n                   0.006          0.005          0.004
#                 word_n                  0.006          0.005          0.004
# zunyi_n         conference_n            0.006          0.005          0.004
# zurich_n        acm_n                   0.006          0.005          0.004
#                 agreement_n             0.006          0.005          0.004
#                 chamber_n               0.006          0.005          0.004
#                 conference_n            0.006          0.005          0.004
#                 government_n            0.006          0.005          0.004
#                 seminar_n               0.006          0.005          0.004
# zwemmer_n       gallery_n               0.006          0.005          0.004
# zwinglische_n   reformation_n           0.006          0.005          0.004
# zwitterion_n    form_n                  0.006          0.005          0.004
#                 intermediate_n          0.006          0.005          0.004
#                 mechanism_n             0.006          0.005          0.004
#                 route_n                 0.006          0.005          0.004
# zygapophyseal_n joint_n                 0.006          0.005          0.004
# zygote_n        nucleus_n               0.006          0.005          0.004
#                 result_n                0.006          0.005          0.004
# zygotene_n      stage_n                 0.006          0.005          0.004
# zylobalsamum_n  process_n               0.006          0.005          0.004
#
#                                 1830_local_mi  1840_local_mi  1850_local_mi  \
# modifier        head
# a_n             aaaaa_n                 0.003          0.003          0.002
#                 addison_n               0.003          0.003          0.002
#                 anti_n                  0.003          0.003          0.002
#                 archive_n               0.003          0.003          0.002
#                 atom_n                  0.003          0.003          0.002
#                 b_n                     0.006          0.007          0.008
#                 band_n                  0.003          0.003          0.002
#                 baseball_n              0.003          0.003          0.002
#                 behavior_n              0.003          0.003          0.002
#                 bell_n                  0.003          0.003          0.002
#                 berkley_n               0.003          0.003          0.002
#                 bibliography_n          0.003          0.003          0.002
#                 bill_n                  0.003          0.003          0.002
#                 bird_n                  0.003          0.003          0.002
#                 board_n                 0.003          0.003          0.002
#                 book_n                  0.003          0.003          0.002
#                 boswell_n               0.003          0.003          0.002
#                 brand_n                 0.003          0.003          0.002
#                 briefe_n                0.003          0.003          0.002
#                 bunch_n                 0.003          0.003          0.002
#                 burn_n                  0.003          0.003          0.002
#                 c_n                     0.004          0.003          0.002
#                 calendar_n              0.003          0.003          0.002
#                 call_n                  0.003          0.003          0.002
#                 campaign_n              0.003          0.003          0.002
#                 cassell_n               0.003          0.003          0.002
#                 cat_n                   0.003          0.003          0.002
#                 cataloguing_n           0.003          0.003          0.002
#                 cell_n                  0.003          0.003          0.002
#                 century_n               0.003          0.003          0.002
# ...                                       ...            ...            ...
# zuni_n          mountain_n              0.003          0.003          0.002
#                 origin_n                0.003          0.003          0.002
#                 prehistory_n            0.003          0.003          0.002
#                 religion_n              0.003          0.003          0.002
#                 ruin_n                  0.003          0.003          0.002
#                 sacred_n                0.003          0.003          0.002
#                 social_n                0.003          0.003          0.002
#                 tradition_n             0.003          0.003          0.002
#                 tribe_n                 0.003          0.003          0.002
#                 village_n               0.003          0.003          0.002
#                 war_n                   0.003          0.003          0.002
#                 word_n                  0.003          0.003          0.002
# zunyi_n         conference_n            0.003          0.003          0.002
# zurich_n        acm_n                   0.003          0.003          0.002
#                 agreement_n             0.003          0.003          0.002
#                 chamber_n               0.003          0.003          0.002
#                 conference_n            0.003          0.003          0.002
#                 government_n            0.003          0.004          0.002
#                 seminar_n               0.003          0.003          0.002
# zwemmer_n       gallery_n               0.003          0.003          0.002
# zwinglische_n   reformation_n           0.003          0.003          0.002
# zwitterion_n    form_n                  0.003          0.003          0.002
#                 intermediate_n          0.003          0.003          0.002
#                 mechanism_n             0.003          0.003          0.002
#                 route_n                 0.003          0.003          0.002
# zygapophyseal_n joint_n                 0.003          0.003          0.002
# zygote_n        nucleus_n               0.003          0.003          0.002
#                 result_n                0.003          0.003          0.002
# zygotene_n      stage_n                 0.003          0.003          0.002
# zylobalsamum_n  process_n               0.003          0.003          0.002
#
#                                 1860_local_mi  1870_local_mi  1880_local_mi  \
# modifier        head
# a_n             aaaaa_n                 0.002          0.001          0.001
#                 addison_n               0.002          0.001          0.001
#                 anti_n                  0.002          0.001          0.001
#                 archive_n               0.002          0.001          0.001
#                 atom_n                  0.002          0.001          0.001
#                 b_n                     0.011          0.012          0.016
#                 band_n                  0.002          0.001          0.001
#                 baseball_n              0.002          0.001          0.001
#                 behavior_n              0.002          0.001          0.001
#                 bell_n                  0.002          0.001          0.001
#                 berkley_n               0.002          0.001          0.001
#                 bibliography_n          0.002          0.001          0.001
#                 bill_n                  0.002          0.001          0.001
#                 bird_n                  0.002          0.001          0.001
#                 board_n                 0.002          0.001          0.001
#                 book_n                  0.002          0.001          0.001
#                 boswell_n               0.002          0.001          0.001
#                 brand_n                 0.002          0.001          0.001
#                 briefe_n                0.002          0.001          0.001
#                 bunch_n                 0.002          0.001          0.001
#                 burn_n                  0.002          0.001          0.001
#                 c_n                     0.002          0.001          0.002
#                 calendar_n              0.002          0.001          0.001
#                 call_n                  0.002          0.001          0.001
#                 campaign_n              0.002          0.001          0.001
#                 cassell_n               0.002          0.001          0.001
#                 cat_n                   0.002          0.001          0.001
#                 cataloguing_n           0.002          0.001          0.001
#                 cell_n                  0.002          0.001          0.001
#                 century_n               0.002          0.001          0.001
# ...                                       ...            ...            ...
# zuni_n          mountain_n              0.002          0.001          0.001
#                 origin_n                0.002          0.001          0.001
#                 prehistory_n            0.002          0.001          0.001
#                 religion_n              0.002          0.001          0.001
#                 ruin_n                  0.002          0.001          0.001
#                 sacred_n                0.002          0.001          0.001
#                 social_n                0.002          0.001          0.001
#                 tradition_n             0.002          0.001          0.001
#                 tribe_n                 0.002          0.001          0.001
#                 village_n               0.002          0.001          0.001
#                 war_n                   0.002          0.001          0.001
#                 word_n                  0.002          0.001          0.001
# zunyi_n         conference_n            0.002          0.001          0.001
# zurich_n        acm_n                   0.002          0.001          0.001
#                 agreement_n             0.002          0.001          0.001
#                 chamber_n               0.002          0.001          0.001
#                 conference_n            0.002          0.001          0.001
#                 government_n            0.002          0.002          0.001
#                 seminar_n               0.002          0.001          0.001
# zwemmer_n       gallery_n               0.002          0.001          0.001
# zwinglische_n   reformation_n           0.002          0.001          0.001
# zwitterion_n    form_n                  0.002          0.001          0.001
#                 intermediate_n          0.002          0.001          0.001
#                 mechanism_n             0.002          0.001          0.001
#                 route_n                 0.002          0.001          0.001
# zygapophyseal_n joint_n                 0.002          0.001          0.001
# zygote_n        nucleus_n               0.002          0.001          0.001
#                 result_n                0.002          0.001          0.001
# zygotene_n      stage_n                 0.002          0.001          0.001
# zylobalsamum_n  process_n               0.002          0.001          0.001
#
#                                 1890_local_mi           ...            \
# modifier        head                                    ...
# a_n             aaaaa_n                 0.002           ...
#                 addison_n               0.002           ...
#                 anti_n                  0.002           ...
#                 archive_n               0.002           ...
#                 atom_n                  0.002           ...
#                 b_n                     0.025           ...
#                 band_n                  0.002           ...
#                 baseball_n              0.002           ...
#                 behavior_n              0.002           ...
#                 bell_n                  0.002           ...
#                 berkley_n               0.002           ...
#                 bibliography_n          0.002           ...
#                 bill_n                  0.002           ...
#                 bird_n                  0.002           ...
#                 board_n                 0.002           ...
#                 book_n                  0.002           ...
#                 boswell_n               0.002           ...
#                 brand_n                 0.002           ...
#                 briefe_n                0.002           ...
#                 bunch_n                 0.002           ...
#                 burn_n                  0.002           ...
#                 c_n                     0.002           ...
#                 calendar_n              0.002           ...
#                 call_n                  0.002           ...
#                 campaign_n              0.002           ...
#                 cassell_n               0.002           ...
#                 cat_n                   0.002           ...
#                 cataloguing_n           0.002           ...
#                 cell_n                  0.002           ...
#                 century_n               0.002           ...
# ...                                       ...           ...
# zuni_n          mountain_n              0.002           ...
#                 origin_n                0.002           ...
#                 prehistory_n            0.002           ...
#                 religion_n              0.002           ...
#                 ruin_n                  0.002           ...
#                 sacred_n                0.002           ...
#                 social_n                0.002           ...
#                 tradition_n             0.002           ...
#                 tribe_n                 0.002           ...
#                 village_n               0.002           ...
#                 war_n                   0.002           ...
#                 word_n                  0.002           ...
# zunyi_n         conference_n            0.002           ...
# zurich_n        acm_n                   0.002           ...
#                 agreement_n             0.002           ...
#                 chamber_n               0.002           ...
#                 conference_n            0.002           ...
#                 government_n            0.002           ...
#                 seminar_n               0.002           ...
# zwemmer_n       gallery_n               0.002           ...
# zwinglische_n   reformation_n           0.002           ...
# zwitterion_n    form_n                  0.002           ...
#                 intermediate_n          0.002           ...
#                 mechanism_n             0.002           ...
#                 route_n                 0.002           ...
# zygapophyseal_n joint_n                 0.002           ...
# zygote_n        nucleus_n               0.002           ...
#                 result_n                0.002           ...
# zygotene_n      stage_n                 0.002           ...
# zylobalsamum_n  process_n               0.002           ...
#
#                                 1900_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.000
#                 addison_n                        0.000
#                 anti_n                           0.000
#                 archive_n                        0.000
#                 atom_n                           0.000
#                 b_n                              0.467
#                 band_n                           0.000
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.000
#                 berkley_n                        0.000
#                 bibliography_n                   0.093
#                 bill_n                           0.000
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.000
#                 brand_n                          0.000
#                 briefe_n                         0.000
#                 bunch_n                          0.000
#                 burn_n                           0.000
#                 c_n                              0.140
#                 calendar_n                       0.000
#                 call_n                           0.000
#                 campaign_n                       0.000
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.000
#                 century_n                        0.099
# ...                                                ...
# zuni_n          mountain_n                       0.000
#                 origin_n                         0.000
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.000
#                 sacred_n                         0.000
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.000
#                 village_n                        0.000
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.000
#                 agreement_n                      0.000
#                 chamber_n                        0.000
#                 conference_n                     0.000
#                 government_n                     0.414
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        0.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.000
# zygotene_n      stage_n                          0.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1910_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.000
#                 addison_n                        0.000
#                 anti_n                           0.000
#                 archive_n                        0.000
#                 atom_n                           0.000
#                 b_n                              0.385
#                 band_n                           0.000
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.000
#                 berkley_n                        0.000
#                 bibliography_n                   0.000
#                 bill_n                           0.000
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.000
#                 brand_n                          0.000
#                 briefe_n                         0.000
#                 bunch_n                          0.000
#                 burn_n                           0.000
#                 c_n                              0.111
#                 calendar_n                       0.000
#                 call_n                           0.000
#                 campaign_n                       0.031
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.123
#                 century_n                        0.095
# ...                                                ...
# zuni_n          mountain_n                       0.000
#                 origin_n                         0.000
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.000
#                 sacred_n                         0.000
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.170
#                 village_n                        0.000
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.000
#                 agreement_n                      0.000
#                 chamber_n                        0.000
#                 conference_n                     0.000
#                 government_n                     0.377
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        0.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.000
# zygotene_n      stage_n                          0.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1920_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.000
#                 addison_n                        0.000
#                 anti_n                           0.000
#                 archive_n                        0.000
#                 atom_n                           0.000
#                 b_n                              0.371
#                 band_n                           0.000
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.000
#                 berkley_n                        0.000
#                 bibliography_n                   0.131
#                 bill_n                           0.000
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.142
#                 brand_n                          0.000
#                 briefe_n                         0.000
#                 bunch_n                          0.000
#                 burn_n                           0.000
#                 c_n                              0.142
#                 calendar_n                       0.000
#                 call_n                           0.000
#                 campaign_n                       0.000
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.000
#                 century_n                        0.144
# ...                                                ...
# zuni_n          mountain_n                       0.000
#                 origin_n                         0.000
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.313
#                 sacred_n                         0.000
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.000
#                 village_n                        0.000
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.000
#                 agreement_n                      0.000
#                 chamber_n                        0.000
#                 conference_n                     0.000
#                 government_n                     0.000
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        0.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.000
# zygotene_n      stage_n                          0.000
# zylobalsamum_n  process_n                        1.000
#
#                                 1930_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.000
#                 addison_n                        0.000
#                 anti_n                           0.000
#                 archive_n                        0.000
#                 atom_n                           0.000
#                 b_n                              0.388
#                 band_n                           0.000
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.000
#                 berkley_n                        0.000
#                 bibliography_n                   0.140
#                 bill_n                           0.000
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.160
#                 brand_n                          0.000
#                 briefe_n                         0.000
#                 bunch_n                          0.000
#                 burn_n                           0.000
#                 c_n                              0.138
#                 calendar_n                       0.000
#                 call_n                           0.000
#                 campaign_n                       0.000
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.000
#                 century_n                        0.131
# ...                                                ...
# zuni_n          mountain_n                       0.000
#                 origin_n                         0.000
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.289
#                 sacred_n                         0.000
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.000
#                 village_n                        0.000
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.000
#                 agreement_n                      0.000
#                 chamber_n                        0.000
#                 conference_n                     0.000
#                 government_n                     0.000
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        0.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.000
# zygotene_n      stage_n                          0.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1940_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.000
#                 addison_n                        0.000
#                 anti_n                           0.000
#                 archive_n                        0.000
#                 atom_n                           0.037
#                 b_n                              0.345
#                 band_n                           0.000
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.000
#                 berkley_n                        0.000
#                 bibliography_n                   0.146
#                 bill_n                           0.000
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.000
#                 brand_n                          0.000
#                 briefe_n                         0.082
#                 bunch_n                          0.000
#                 burn_n                           0.000
#                 c_n                              0.154
#                 calendar_n                       0.000
#                 call_n                           0.000
#                 campaign_n                       0.025
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.000
#                 century_n                        0.179
# ...                                                ...
# zuni_n          mountain_n                       0.000
#                 origin_n                         0.000
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.000
#                 sacred_n                         0.000
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.354
#                 village_n                        0.000
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.000
#                 agreement_n                      0.000
#                 chamber_n                        0.000
#                 conference_n                     0.000
#                 government_n                     0.000
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        0.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.000
# zygotene_n      stage_n                          0.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1950_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.000
#                 addison_n                        0.000
#                 anti_n                           0.000
#                 archive_n                        0.000
#                 atom_n                           0.067
#                 b_n                              0.303
#                 band_n                           0.000
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.000
#                 berkley_n                        0.000
#                 bibliography_n                   0.167
#                 bill_n                           0.045
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.000
#                 brand_n                          0.000
#                 briefe_n                         0.072
#                 bunch_n                          0.082
#                 burn_n                           0.000
#                 c_n                              0.143
#                 calendar_n                       0.000
#                 call_n                           0.000
#                 campaign_n                       0.025
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.000
#                 century_n                        0.169
# ...                                                ...
# zuni_n          mountain_n                       0.111
#                 origin_n                         0.334
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.000
#                 sacred_n                         0.000
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.346
#                 village_n                        0.000
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.000
#                 agreement_n                      0.000
#                 chamber_n                        0.000
#                 conference_n                     0.311
#                 government_n                     0.309
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        0.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.000
# zygotene_n      stage_n                          0.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1960_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.059
#                 addison_n                        0.049
#                 anti_n                           0.072
#                 archive_n                        0.102
#                 atom_n                           0.064
#                 b_n                              0.257
#                 band_n                           0.069
#                 baseball_n                       0.000
#                 behavior_n                       0.000
#                 bell_n                           0.105
#                 berkley_n                        0.000
#                 bibliography_n                   0.152
#                 bill_n                           0.026
#                 bird_n                           0.000
#                 board_n                          0.000
#                 book_n                           0.000
#                 boswell_n                        0.000
#                 brand_n                          0.000
#                 briefe_n                         0.063
#                 bunch_n                          0.095
#                 burn_n                           0.000
#                 c_n                              0.119
#                 calendar_n                       0.032
#                 call_n                           0.000
#                 campaign_n                       0.025
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.046
#                 century_n                        0.173
# ...                                                ...
# zuni_n          mountain_n                       0.000
#                 origin_n                         0.389
#                 prehistory_n                     0.000
#                 religion_n                       0.000
#                 ruin_n                           0.233
#                 sacred_n                         0.203
#                 social_n                         0.000
#                 tradition_n                      0.000
#                 tribe_n                          0.325
#                 village_n                        0.295
#                 war_n                            0.000
#                 word_n                           0.000
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.159
#                 agreement_n                      0.382
#                 chamber_n                        0.000
#                 conference_n                     0.304
#                 government_n                     0.243
#                 seminar_n                        0.000
# zwemmer_n       gallery_n                        1.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           0.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.000
#                 result_n                         0.573
# zygotene_n      stage_n                          1.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1970_sim_with_modifier  \
# modifier        head
# a_n             aaaaa_n                          0.054
#                 addison_n                        0.054
#                 anti_n                           0.063
#                 archive_n                        0.103
#                 atom_n                           0.052
#                 b_n                              0.217
#                 band_n                           0.107
#                 baseball_n                       0.000
#                 behavior_n                       0.036
#                 bell_n                           0.111
#                 berkley_n                        0.000
#                 bibliography_n                   0.172
#                 bill_n                           0.037
#                 bird_n                           0.008
#                 board_n                          0.052
#                 book_n                           0.045
#                 boswell_n                        0.000
#                 brand_n                          0.000
#                 briefe_n                         0.061
#                 bunch_n                          0.075
#                 burn_n                           0.000
#                 c_n                              0.112
#                 calendar_n                       0.022
#                 call_n                           0.000
#                 campaign_n                       0.022
#                 cassell_n                        0.000
#                 cat_n                            0.000
#                 cataloguing_n                    0.000
#                 cell_n                           0.058
#                 century_n                        0.159
# ...                                                ...
# zuni_n          mountain_n                       0.098
#                 origin_n                         0.340
#                 prehistory_n                     0.170
#                 religion_n                       0.086
#                 ruin_n                           0.214
#                 sacred_n                         0.198
#                 social_n                         0.127
#                 tradition_n                      0.000
#                 tribe_n                          0.296
#                 village_n                        0.276
#                 war_n                            0.000
#                 word_n                           0.198
# zunyi_n         conference_n                     0.000
# zurich_n        acm_n                            0.145
#                 agreement_n                      0.398
#                 chamber_n                        0.142
#                 conference_n                     0.311
#                 government_n                     0.000
#                 seminar_n                        0.253
# zwemmer_n       gallery_n                        1.000
# zwinglische_n   reformation_n                    0.000
# zwitterion_n    form_n                           1.000
#                 intermediate_n                   0.000
#                 mechanism_n                      0.000
#                 route_n                          0.000
# zygapophyseal_n joint_n                          0.000
# zygote_n        nucleus_n                        0.559
#                 result_n                         0.580
# zygotene_n      stage_n                          1.000
# zylobalsamum_n  process_n                        0.000
#
#                                 1980_sim_with_modifier  1990_sim_with_modifier
# modifier        head
# a_n             aaaaa_n                          0.053                   0.048
#                 addison_n                        0.057                   0.051
#                 anti_n                           0.059                   0.055
#                 archive_n                        0.090                   0.073
#                 atom_n                           0.052                   0.051
#                 b_n                              0.188                   0.190
#                 band_n                           0.099                   0.102
#                 baseball_n                       0.053                   0.067
#                 behavior_n                       0.038                   0.028
#                 bell_n                           0.119                   0.099
#                 berkley_n                        0.077                   0.060
#                 bibliography_n                   0.164                   0.152
#                 bill_n                           0.035                   0.036
#                 bird_n                           0.013                   0.013
#                 board_n                          0.000                   0.049
#                 book_n                           0.035                   0.000
#                 boswell_n                        0.000                   0.000
#                 brand_n                          0.069                   0.064
#                 briefe_n                         0.057                   0.059
#                 bunch_n                          0.026                   0.070
#                 burn_n                           0.000                   0.097
#                 c_n                              0.107                   0.105
#                 calendar_n                       0.020                   0.000
#                 call_n                           0.000                   0.053
#                 campaign_n                       0.023                   0.021
#                 cassell_n                        0.000                   0.104
#                 cat_n                            0.000                   0.046
#                 cataloguing_n                    0.037                   0.076
#                 cell_n                           0.056                   0.049
#                 century_n                        0.137                   0.132
# ...                                                ...                     ...
# zuni_n          mountain_n                       0.000                   0.083
#                 origin_n                         0.319                   0.261
#                 prehistory_n                     0.161                   0.126
#                 religion_n                       0.086                   0.071
#                 ruin_n                           0.198                   0.182
#                 sacred_n                         0.196                   0.157
#                 social_n                         0.117                   0.100
#                 tradition_n                      0.196                   0.171
#                 tribe_n                          0.282                   0.253
#                 village_n                        0.255                   0.219
#                 war_n                            0.000                   0.113
#                 word_n                           0.171                   0.175
# zunyi_n         conference_n                     1.000                   1.000
# zurich_n        acm_n                            0.137                   0.113
#                 agreement_n                      0.348                   0.298
#                 chamber_n                        0.175                   0.198
#                 conference_n                     0.000                   0.000
#                 government_n                     0.000                   0.000
#                 seminar_n                        0.256                   0.295
# zwemmer_n       gallery_n                        1.000                   1.000
# zwinglische_n   reformation_n                    1.000                   1.000
# zwitterion_n    form_n                           0.000                   0.000
#                 intermediate_n                   0.000                   0.642
#                 mechanism_n                      0.000                   0.313
#                 route_n                          0.000                   0.665
# zygapophyseal_n joint_n                          1.000                   0.910
# zygote_n        nucleus_n                        0.000                   0.000
#                 result_n                         0.581                   0.638
# zygotene_n      stage_n                          1.000                   1.000
# zylobalsamum_n  process_n                        0.000                   0.000
#
# [775566 rows x 120 columns]

# %%
compounds_final.to_csv("/data/dharp/compounding/datasets/dist_sem_dec.csv")

# %%
new_heads=new_heads.reset_index(inplace=True)
new_heads.columns=['constituent','decade','context','ppmi']
new_heads['constituent']=new_heads['constituent'].str.replace(r'_n$', r'_h', regex=True)
new_heads.shape
# Out:
#                                 context  modifier_ppmi
# modifier        decade
# a_n             1830                a_n          8.587
# aa_n            1830                a_n         14.910
# aaa_n           1830                a_n         15.618
# american_n      1830                a_n          4.552
# angle_n         1830                a_n          9.568
# b_n             1830                a_n         10.906
# british_n       1830                a_n          1.389
# c_n             1830                a_n          9.367
# capital_n       1830                a_n          1.643
# catalog_n       1830                a_n         13.103
# chronometer_n   1830                a_n         13.103
# class_n         1830                a_n          6.294
# comprehensive_n 1830                a_n         11.579
# conjugate_n     1830                a_n         11.196
# d_n             1830                a_n         10.871
# direction_n     1830                a_n         12.146
# e_n             1830                a_n          8.361
# estate_n        1830                a_n          8.413
# f_n             1830                a_n          9.160
# g_n             1830                a_n          7.572
# general_n       1830                a_n          2.216
# glass_n         1830                a_n          3.444
# grammatical_n   1830                a_n         14.103
# h_n             1830                a_n         12.518
# heirs_n         1830                a_n          7.631
# l_n             1830                a_n         12.330
# line_n          1830                a_n          9.434
# lines_n         1830                a_n         11.063
# m_n             1830                a_n         11.257
# n_n             1830                a_n         12.015
# ...                                 ...            ...
# x_n             1860                v_v         16.560
#                 1860                z_v         16.560
# yale_n          1860             ezra_n         11.378
#                 1860         silliman_n         12.274
#                 1860    undergraduate_a         11.378
#                 1860          woolsey_n         12.400
# year_n          1860           plague_a         11.752
#                 1860             wirt_n         11.856
#                 1860         yearling_n         11.936
# yearning_n      1860        leisurely_a         16.436
# years_n         1860          brescia_n         11.752
#                 1860       epiphanius_n         10.922
#                 1860         thousand_a         11.422
# yeomanly_n      1860       challenger_n         20.999
# yesterday_n     1860             tree_a         12.732
# yew_n           1860          clipped_a         17.277
# yoga_n          1860        patanjali_n         20.976
# yom_n           1860             rosh_n         23.749
# york_n          1860         atheneum_n          9.408
#                 1860           fabric_a          9.738
#                 1860              now_n          8.908
#                 1860          shipper_n          8.908
#                 1860      therapeutic_a          9.408
# young_n         1860           assist_n         12.227
#                 1860        finishing_n         11.066
#                 1860          majorca_n         11.066
#                 1860             tony_n         12.066
# zoological_n    1860     hippopotamus_n         12.941
#                 1860         kangaroo_n         12.691
# zurich_n        1860          strauss_n         19.057
#
# [23495976 rows x 2 columns]
