# %%
import pandas as pd
import random
import glob
import multiprocessing as mp
from multiprocessing import Pool
import argparse
import numpy as np
from itertools import repeat
import time

# %%
parser = argparse.ArgumentParser(description='Program to combine pickle data into one file for all settings')

parser.add_argument('--setting', type=str,
                    help='phr:Phrases const:Constituent')

parser.add_argument('--ipath', type=str,
                    help='directory where to load the datasets from')
parser.add_argument('--spath', type=str,
                    help='directory where to save output')

args = parser.parse_args("--setting phr --ipath /datanaco/dharp/compounds/datasets/ --spath /datanaco/dharp/compounds/datasets/phrases_temp///".split())

# %%
if args.setting=="phr":
    pkl_files=glob.glob(f'{args.ipath}/phrases/*pkl')
    
elif args.setting=="const":
    pkl_files=glob.glob(f'{args.ipath}/words/*pkl')

# %%
random.shuffle(pkl_files)
div_lsts=np.array_split(pkl_files, 5)

dec_list=list(range(1810,2020,10))
len(div_lsts[0])
# Out:
# 23

# %%
def process_dataset(f,dec):
    cur_time=time.time()
    df=pd.read_pickle(f)
    if dec==1790:
        df=df.loc[df.year<1800]
    else:
        df=df.loc[df.year.between(dec,dec+9,inclusive='both')]
    
    if args.setting=='phr':
        df=df.groupby(['modifier','head','year','context'],observed=True)['count'].sum().to_frame()
    else:
        df=df.groupby(['word','year','context'],observed=True)['count'].sum().to_frame()

    df.reset_index(inplace=True)
    print(f'Done with file {f} in {time.time()-cur_time} secs')
    return df

# %%
def batch_processor(cur_list,dec):
    cur_time=time.time()

    dfs=[]
    n_proc = len(cur_list)
    pool = Pool(n_proc)
    dfs=pool.starmap(process_dataset, zip(cur_list,repeat(dec)))
    pool.close()
    pool.join()  
    
    print('Done parallelizing')
    combined_df=pd.concat(dfs,ignore_index=True,sort=True)
    orig_shape=combined_df.shape[0]

    if args.setting=="phr":
        df_reduced=combined_df.groupby(['modifier','head','context','year'],observed=True)['count'].sum().to_frame().reset_index()
        
    else:
        df_reduced=combined_df.groupby(['word','context','year'],observed=True)['count'].sum().to_frame().reset_index()
        
        
    print(f'Done with batch in {round(time.time()-cur_time)} secs and current size is {round(df_reduced.shape[0]/orig_shape*100,2)}% of the original dataset')

    return df_reduced

# %%
for dec in dec_list:
    print(dec)
    for i,cur_list in enumerate(div_lsts):
        print(f'Batch {i+1}')
        cur_time=time.time()


        cur_df=batch_processor(cur_list,dec)

        cur_df.to_pickle(f'{args.spath}/{args.setting}_{dec}_{i+1}')
        print(f'Time taken for batch {i+1} = {time.time()-cur_time} secs')
# Out:
# Batch 1
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_8.pkl in 449.10279536247253 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_15.pkl in 672.2273349761963 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_13.pkl in 736.1096456050873 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_40.pkl in 871.5937917232513 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_6.pkl in 891.5167787075043 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_36.pkl in 899.8529374599457 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_66.pkl in 917.8218274116516 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_22.pkl in 1010.9095845222473 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_87.pkl in 1029.8078973293304 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_74.pkl in 1040.4653549194336 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_83.pkl in 1133.3749706745148 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_80.pkl in 1149.5280389785767 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_88.pkl in 1152.727877855301 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_50.pkl in 1184.7855505943298 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_59.pkl in 1203.3997719287872 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_101.pkl in 1208.4560916423798 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_48.pkl in 1208.7565712928772 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_103.pkl in 1215.0576779842377 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_92.pkl in 1227.2369735240936 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_58.pkl in 1240.3155014514923 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_100.pkl in 1245.4756181240082 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_102.pkl in 1246.399465084076 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_112.pkl in 1370.514634847641 secs
# Done parallelizing
# Done with batch in 1378 secs and current size is 81.11% of the original dataset
# Time taken for batch 1 = 1379.7600378990173 secs
# Batch 2
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_7.pkl in 521.5940392017365 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_2.pkl in 593.5958468914032 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_115.pkl in 782.1727213859558 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_67.pkl in 827.5154337882996 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_29.pkl in 836.6547870635986 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_33.pkl in 865.7541737556458 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_68.pkl in 879.6454916000366 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_41.pkl in 954.9292616844177 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_32.pkl in 964.1200654506683 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_24.pkl in 975.69415974617 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_28.pkl in 993.681640625 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_61.pkl in 1015.0737109184265 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_60.pkl in 1033.4993958473206 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_69.pkl in 1036.1123423576355 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_54.pkl in 1037.7126076221466 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_70.pkl in 1052.1847522258759 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_96.pkl in 1098.6105031967163 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_82.pkl in 1136.5924334526062 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_47.pkl in 1171.148336648941 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_104.pkl in 1182.2085947990417 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_49.pkl in 1231.2950682640076 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_108.pkl in 1257.8970992565155 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_113.pkl in 1308.4947018623352 secs
# Done parallelizing
# Done with batch in 1316 secs and current size is 80.36% of the original dataset
# Time taken for batch 2 = 1321.3385970592499 secs
# Batch 3
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_9.pkl in 499.31835103034973 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_19.pkl in 576.6317336559296 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_16.pkl in 684.8989796638489 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_4.pkl in 764.6240632534027 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_12.pkl in 800.1058373451233 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_5.pkl in 811.2580237388611 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_26.pkl in 845.7965183258057 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_42.pkl in 849.6809103488922 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_18.pkl in 881.7036316394806 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_71.pkl in 882.3106806278229 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_72.pkl in 906.3969974517822 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_76.pkl in 911.9751708507538 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_10.pkl in 930.2430627346039 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_91.pkl in 968.9148278236389 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_53.pkl in 975.5257966518402 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_73.pkl in 992.9484939575195 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_38.pkl in 996.897497177124 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_84.pkl in 1022.6098010540009 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_99.pkl in 1034.8919925689697 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_98.pkl in 1052.7935297489166 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_46.pkl in 1107.7193176746368 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_107.pkl in 1118.5742771625519 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_52.pkl in 1142.0914704799652 secs
# Done parallelizing
# Done with batch in 1149 secs and current size is 79.3% of the original dataset
# Time taken for batch 3 = 1162.2003600597382 secs
# Batch 4
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_1.pkl in 588.4089415073395 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_11.pkl in 746.8463137149811 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_21.pkl in 851.9052393436432 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_20.pkl in 859.6583364009857 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_34.pkl in 958.264634847641 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_35.pkl in 969.4038536548615 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_65.pkl in 1018.8334827423096 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_85.pkl in 1151.0362572669983 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_79.pkl in 1163.765611410141 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_75.pkl in 1205.7044610977173 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_94.pkl in 1231.0996434688568 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_37.pkl in 1243.6501603126526 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_57.pkl in 1261.6450123786926 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_45.pkl in 1293.0533819198608 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_77.pkl in 1304.141393661499 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_78.pkl in 1318.322823047638 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_51.pkl in 1323.0669929981232 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_31.pkl in 1326.6467621326447 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_43.pkl in 1362.5947616100311 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_105.pkl in 1404.7642667293549 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_109.pkl in 1505.6473715305328 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_114.pkl in 1536.4592247009277 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_111.pkl in 1551.787312746048 secs
# Done parallelizing
# Done with batch in 1562 secs and current size is 79.26% of the original dataset
# Time taken for batch 4 = 1572.899219751358 secs
# Batch 5
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_63.pkl in 728.6332430839539 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_3.pkl in 926.3413763046265 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_14.pkl in 1012.7327566146851 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_62.pkl in 1083.60178232193 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_39.pkl in 1169.1974325180054 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_23.pkl in 1169.840796470642 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_27.pkl in 1170.764719247818 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_17.pkl in 1175.5013976097107 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_64.pkl in 1185.1625247001648 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_30.pkl in 1210.3066039085388 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_89.pkl in 1227.2753880023956 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_93.pkl in 1258.3416800498962 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_97.pkl in 1286.894748210907 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_90.pkl in 1331.6958179473877 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_86.pkl in 1347.840012550354 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_95.pkl in 1357.6705315113068 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_55.pkl in 1368.8508412837982 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_25.pkl in 1382.5768384933472 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_81.pkl in 1384.7538409233093 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_106.pkl in 1420.2760372161865 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_56.pkl in 1440.9755127429962 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_44.pkl in 1471.6430869102478 secs
# Done with file /datanaco/dharp/compounds/datasets//phrases/df_110.pkl in 1501.569086074829 secs
# Done parallelizing
# Done with batch in 1510 secs and current size is 77.35% of the original dataset
# Time taken for batch 5 = 1515.1377058029175 secs
