# %%
import random
import pandas as pd
import glob
import numpy as np
import time
import multiprocessing as mp
from multiprocessing import Pool

# %%
pkl_files=glob.glob('/data/dharp/compounds/datasets/phrases/*pkl')
random.shuffle(pkl_files)
len(pkl_files)
# Out:
# 115

# %%
div_lsts=np.array_split(pkl_files, 5)

# %%
len(div_lsts[0])
# Out:
# 23

# %%
keep_string=r"^.+_(PROPN|NOUN|ADJ|VERB||NUM|ADV)$"

# %%
def mem_reducer(pkl_file):
    print(f'\nStarted with file {pkl_file}\n')
    cur_time=time.time()
    
    df=pd.read_pickle(pkl_file)
    df=df.groupby(['context','year'])['count'].sum().to_frame().reset_index()

    context_df=pd.DataFrame(df['context'].unique())
    context_df=context_df.loc[~context_df[0].str.contains('@@@')]
    context_words=context_df.loc[context_df[0].str.match(keep_string)][0].to_list()
    df=df.loc[df.context.isin(context_words)]
    df.context=df.context.str.replace(r'.+_NUM','NUM',regex=True)
    df["year"] = pd.to_numeric(df["year"], downcast="unsigned")
    df=df.groupby(['context','year'])['count'].sum().to_frame().reset_index()
    print(f'Done with file {pkl_file} in {round(time.time()-cur_time)} secs')
    return df

# %%
entire_context_df_list=[]
for i,cur_list in enumerate(div_lsts):
    print(f'List num {i+1}')
    n_proc = len(cur_list)

    pool = Pool(n_proc)
    results=pool.map_async(mem_reducer,cur_list) 
    pool.close()
    pool.join()
    
    dfs=results.get()
    
    cur_df=pd.concat(dfs,ignore_index=True,sort=True)
    
    display(cur_df.info())
    
    cur_df=cur_df.groupby(['context','year'])['count'].sum().to_frame().reset_index()
    
    display(cur_df.info())
    
    entire_context_df_list.append(cur_df)
# Out:
# List num 1
#
# Started with file /data/dharp/compounds/datasets/phrases/df_39.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_29.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_67.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_31.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_114.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_99.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_30.pkl
#
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_22.pkl
#
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_12.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_78.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_111.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_75.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_38.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_66.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_100.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_36.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_95.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_27.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_76.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_47.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_10.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_60.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_62.pkl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done with file /data/dharp/compounds/datasets/phrases/df_67.pkl in 855 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_12.pkl in 895 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_36.pkl in 957 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_62.pkl in 970 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_29.pkl in 997 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_66.pkl in 997 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_76.pkl in 1058 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_60.pkl in 1067 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_22.pkl in 1085 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_10.pkl in 1098 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_27.pkl in 1101 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_39.pkl in 1119 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_30.pkl in 1151 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_38.pkl in 1160 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_75.pkl in 1179 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_99.pkl in 1206 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_31.pkl in 1279 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_78.pkl in 1284 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_95.pkl in 1291 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_47.pkl in 1295 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_100.pkl in 1297 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_114.pkl in 1480 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_111.pkl in 1491 secs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137482085 entries, 0 to 137482084
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   count    int64
#  2   year     uint64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 3.1+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41078291 entries, 0 to 41078290
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   year     uint64
#  2   count    int64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 940.2+ MB
# None
# List num 2
#
# Started with file /data/dharp/compounds/datasets/phrases/df_113.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_63.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_89.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_73.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_81.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_35.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_14.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_48.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_1.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_23.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_32.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_58.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_64.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_97.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_104.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_4.pkl
#
#
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_51.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_82.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_18.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_92.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_96.pkl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_26.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_65.pkl
#
#
# Done with file /data/dharp/compounds/datasets/phrases/df_1.pkl in 699 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_63.pkl in 813 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_4.pkl in 876 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_26.pkl in 883 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_65.pkl in 906 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_18.pkl in 909 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_14.pkl in 961 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_32.pkl in 1020 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_35.pkl in 1028 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_23.pkl in 1091 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_73.pkl in 1097 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_64.pkl in 1112 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_89.pkl in 1141 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_96.pkl in 1158 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_48.pkl in 1221 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_97.pkl in 1225 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_51.pkl in 1227 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_92.pkl in 1231 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_82.pkl in 1238 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_81.pkl in 1254 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_58.pkl in 1257 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_104.pkl in 1277 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_113.pkl in 1395 secs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134798662 entries, 0 to 134798661
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   count    int64
#  2   year     uint64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 3.0+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39087070 entries, 0 to 39087069
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   year     uint64
#  2   count    int64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 894.6+ MB
# None
# List num 3
#
# Started with file /data/dharp/compounds/datasets/phrases/df_21.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_50.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_9.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_69.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_54.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_40.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_88.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_94.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_68.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_72.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_42.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_93.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_86.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_5.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_98.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_43.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_77.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_84.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_7.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_74.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_45.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_112.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_2.pkl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done with file /data/dharp/compounds/datasets/phrases/df_9.pkl in 538 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_7.pkl in 582 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_2.pkl in 621 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_5.pkl in 803 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_21.pkl in 805 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_40.pkl in 844 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_42.pkl in 855 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_68.pkl in 879 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_72.pkl in 894 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_54.pkl in 1013 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_69.pkl in 1027 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_74.pkl in 1032 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_88.pkl in 1084 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_84.pkl in 1091 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_94.pkl in 1121 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_93.pkl in 1126 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_50.pkl in 1127 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_45.pkl in 1139 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_77.pkl in 1141 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_98.pkl in 1150 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_86.pkl in 1160 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_43.pkl in 1169 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_112.pkl in 1334 secs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120523976 entries, 0 to 120523975
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   count    int64
#  2   year     uint64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 2.7+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36204589 entries, 0 to 36204588
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   year     uint64
#  2   count    int64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 828.7+ MB
# None
# List num 4
#
# Started with file /data/dharp/compounds/datasets/phrases/df_101.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_71.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_33.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_91.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_90.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_24.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_6.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_57.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_20.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_115.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_85.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_41.pkl
#
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_108.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_61.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_87.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_59.pkl
#
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_11.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_44.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_52.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_19.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_80.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_25.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_15.pkl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done with file /data/dharp/compounds/datasets/phrases/df_11.pkl in 712 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_15.pkl in 723 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_19.pkl in 725 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_20.pkl in 778 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_115.pkl in 870 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_6.pkl in 922 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_33.pkl in 934 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_71.pkl in 941 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_41.pkl in 986 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_61.pkl in 1022 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_24.pkl in 1038 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_87.pkl in 1056 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_85.pkl in 1060 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_91.pkl in 1077 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_80.pkl in 1093 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_57.pkl in 1117 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_101.pkl in 1165 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_59.pkl in 1169 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_90.pkl in 1180 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_25.pkl in 1192 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_44.pkl in 1317 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_52.pkl in 1321 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_108.pkl in 1325 secs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125502942 entries, 0 to 125502941
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   count    int64
#  2   year     uint64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 2.8+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35302301 entries, 0 to 35302300
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   year     uint64
#  2   count    int64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 808.0+ MB
# None
# List num 5
#
# Started with file /data/dharp/compounds/datasets/phrases/df_70.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_34.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_17.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_83.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_55.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_49.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_79.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_105.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_3.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_107.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_13.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_102.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_16.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_46.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_53.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_109.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_28.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_37.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_106.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_56.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_103.pkl
#
# Started with file /data/dharp/compounds/datasets/phrases/df_8.pkl
#
#
# Started with file /data/dharp/compounds/datasets/phrases/df_110.pkl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done with file /data/dharp/compounds/datasets/phrases/df_8.pkl in 591 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_13.pkl in 762 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_16.pkl in 809 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_3.pkl in 935 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_34.pkl in 1058 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_17.pkl in 1112 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_28.pkl in 1118 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_53.pkl in 1158 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_79.pkl in 1161 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_70.pkl in 1232 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_83.pkl in 1243 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_37.pkl in 1272 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_102.pkl in 1402 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_103.pkl in 1402 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_55.pkl in 1413 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_46.pkl in 1465 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_106.pkl in 1500 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_105.pkl in 1507 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_56.pkl in 1511 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_107.pkl in 1521 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_49.pkl in 1531 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_109.pkl in 1607 secs
# Done with file /data/dharp/compounds/datasets/phrases/df_110.pkl in 1615 secs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159572026 entries, 0 to 159572025
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   count    int64
#  2   year     uint64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 3.6+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45236503 entries, 0 to 45236502
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   year     uint64
#  2   count    int64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 1.0+ GB
# None

# %%
context_df=pd.concat(entire_context_df_list,sort=False,ignore_index=True)
context_df.info()
context_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196908754 entries, 0 to 196908753
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   context  object
#  1   year     uint64
#  2   count    int64
# dtypes: int64(1), object(1), uint64(1)
# memory usage: 4.4+ GB
#            context  year  count
# 0            #_ADV  1774      2
# 1            #_ADV  1832      5
# 2            #_ADV  1842      2
# 3            #_ADV  1851      6
# 4            #_ADV  1857      1
# ...            ...   ...    ...
# 196908749  ﹑_PROPN  2007      4
# 196908750    😊_ADJ  2016      5
# 196908751    😊_ADJ  2017     20
# 196908752    😊_ADJ  2018     21
# 196908753    😊_ADJ  2019     10
#
# [196908754 rows x 3 columns]

# %%
context_df=context_df.groupby(['context','year'])['count'].sum().to_frame().reset_index()
context_df
# Out:
#           context  year  count
# 0         "_PROPN  1969      4
# 1         "_PROPN  1970     13
# 2         "_PROPN  1971      2
# 3         "_PROPN  1972      9
# 4         "_PROPN  1975      7
# ...           ...   ...    ...
# 79767104    😊_ADJ  2019     20
# 79767105   😊_NOUN  2016      5
# 79767106   😊_NOUN  2017     20
# 79767107   😊_NOUN  2018     21
# 79767108   😊_NOUN  2019     10
#
# [79767109 rows x 3 columns]

# %%
presence_df=context_df.query('1800 <= year <= 2020').context.value_counts().to_frame()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 presence_df=context_df.query('1800 <= year <= 2020').context.value_counts().to_frame()
#
# File /data/dharp/packages/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:4111, in DataFrame.query(self, expr, inplace, **kwargs)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
# -> 4111 res = self.eval(expr, **kwargs)
#    4113 try:
#    4114     result = self.loc[res]
#
# File /data/dharp/packages/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:4240, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4237     kwargs["target"] = self
#    4238 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4240 return _eval(expr, inplace=inplace, **kwargs)
#
# File /data/dharp/packages/miniconda3/lib/python3.9/site-packages/pandas/core/computation/eval.py:355, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     353 eng = ENGINES[engine]
#     354 eng_inst = eng(parsed_expr)
# --> 355 ret = eng_inst.evaluate()
#     357 if parsed_expr.assigner is None:
#     358     if multi_line:
#
# File /data/dharp/packages/miniconda3/lib/python3.9/site-packages/pandas/core/computation/engines.py:80, in AbstractEngine.evaluate(self)
#      77     self.result_type, self.aligned_axes = align_terms(self.expr.terms)
#      79 # make sure no names in resolvers and locals/globals clash
# ---> 80 res = self._evaluate()
#      81 return reconstruct_object(
#      82     self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#      83 )
#
# File /data/dharp/packages/miniconda3/lib/python3.9/site-packages/pandas/core/computation/engines.py:121, in NumExprEngine._evaluate(self)
#     119 scope = env.full_scope
#     120 _check_ne_builtin_clash(self.expr)
# --> 121 return ne.evaluate(s, local_dict=scope)
#
# File /data/dharp/packages/miniconda3/lib/python3.9/site-packages/numexpr/necompiler.py:827, in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     825 _numexpr_last = dict(ex=compiled_ex, argnames=names, kwargs=kwargs)
#     826 with evaluate_lock:
# --> 827     return compiled_ex(*arguments, **kwargs)
#
# TypeError: Iterator operand 1 dtype could not be cast from dtype('uint64') to dtype('int64') according to the rule 'safe'

# %%
presence_df.loc[presence_df.context>200]
# Out:
#                  context
# rate_NOUN            220
# remote_ADV           220
# beggar_PROPN         220
# beggar_NOUN          220
# jocund_ADJ           220
# ...                  ...
# champs_PROPN         201
# esch_PROPN           201
# consecutive_ADJ      201
# internus_PROPN       201
# mattocks_PROPN       201
#
# [39980 rows x 1 columns]

# %%
years_df=context_df.groupby(['year'])['count'].sum().to_frame().reset_index()
years_df
# Out:
#      year       count
# 0    1470          11
# 1    1472       17953
# 2    1475       27373
# 3    1476         515
# 4    1477       31238
# ..    ...         ...
# 518  2015  1014679053
# 519  2016  1041408305
# 520  2017   973285732
# 521  2018  1178832910
# 522  2019   764507389
#
# [523 rows x 2 columns]

# %%
context_df.to_pickle('/data/dharp/compounds/datasets/contexts/contexts.pkl')

# %%
content_words_df=context_df.groupby(['context'])['count'].sum().to_frame().reset_index()

# %%
content_words_df.sort_values(by='count')
# Out:
#                     context       count
# 259936       chantelle_NOUN          40
# 1450571        umptek_PROPN          40
# 644041            huic_NOUN          40
# 977689   nonovulation_PROPN          40
# 186932       borborch_PROPN          40
# ...                     ...         ...
# 40615             act_PROPN   582316180
# 603279            have_VERB   587375929
# 1457954        united_PROPN   646937825
# 959876            new_PROPN  1072819343
# 26879                   NUM  5850773534
#
# [1575989 rows x 2 columns]
